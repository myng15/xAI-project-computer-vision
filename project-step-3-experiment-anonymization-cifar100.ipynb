# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/xAI-project-computer-vision

import sys
sys.path.insert(0,'/content/drive/My Drive/Github/xAI-project-computer-vision')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github/xAI-project-computer-vision

# %%
# !pip install torchinfo

# %%
import numpy as np
import random
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import datasets

print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.1.0+cu121
# torchvision version: 0.16.0+cu121

# %%
import models
from utils import print_model_summary, get_available_device, move_to_device, seed_all

device = get_available_device()
print("Device:", device)

seed_all(42)
# Out:
# Device: cuda
#
# Device: cuda
# Random seed 42 has been set.

# %% [markdown]
# # Anonymize embeddings extracted using simple custom CNNs

# %% [markdown]
# ## Simple custom CNN v1

# %% [markdown]
# ## Simple custom CNN v2

# %% [markdown]
# # Anonymize embeddings extracted using deeper custom CNNs (based on ResNet)

# %% [markdown]
# ## Simplified custom ResNet

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_012640' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'random' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 81.22%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 81.15%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.25): 81.16%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 80.68%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.75): 78.90%
# Figure(640x480)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_134040' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.1):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 55.15%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 54.89%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 54.76%
# Reconstruction Error of Anonymized Train Embeddings: 0.0200
# Reconstruction Error of Anonymized Test Embeddings: 0.0200
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 55.15%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 52.09%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 53.15%
# ...

# %%
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_134040' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'gaussian' --tuning --noise_scale_tuning 0.5 1.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 55.15%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 47.94%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 50.47%
# Reconstruction Error of Anonymized Train Embeddings: 0.2500
# Reconstruction Error of Anonymized Test Embeddings: 0.2501
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=1.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 55.15%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 8.23%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 15.19%
# ...

# %%
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_134040' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 36.19%
# KNN Classifier Accuracy on Original Test Set: 42.61%
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_134040' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 1000 --assign_labels 'majority' --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 37.40%
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# ## Custom ResNet18

# %% [markdown]
# ### Laplace

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 35.25% (Accuracy Loss: 29.22%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 44.40% (Accuracy Loss: 20.07%)
# Reconstruction Error of Anonymized Train Embeddings: 0.4999
# Reconstruction Error of Anonymized Test Embeddings: 0.5009
# Variance Retention of Anonymized Train Embeddings: 6.0344
# Variance Retention of Anonymized Test Embeddings: 6.1594
# Projection Robustness of Anonymized Train Embeddings: 18.5043
# Projection Robustness of Anonymized Test Embeddings: 18.6210
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75 1.0
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.1):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 63.77% (Accuracy Loss: 0.70%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 63.90% (Accuracy Loss: 0.57%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0200
# Reconstruction Error of Anonymized Test Embeddings: 0.0200
# Variance Retention of Anonymized Train Embeddings: 1.2015
# Variance Retention of Anonymized Test Embeddings: 1.2065
# Projection Robustness of Anonymized Train Embeddings: 1.2937
# Projection Robustness of Anonymized Test Embeddings: 1.3117
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ...

# %% [markdown]
# ### PCA

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 10 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 30.01% (Accuracy Loss: 34.46%)
# Variance Retention of Anonymized Train Embeddings: 0.4914
# Variance Retention of Anonymized Test Embeddings: 0.4942
# Projection Robustness of Anonymized Train Embeddings: 3.6270
# Projection Robustness of Anonymized Test Embeddings: 3.5374
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision/visualization.py:196: UserWarning: The palette list has more values (103) than needed (100), which may not be intended.
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --tuning --n_components_tuning 10 20 30

# %% [markdown]
# ### Density-based

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 3 --noise_scale 0.1 --visualize_embeds

# %% [markdown]
# ### K-Means

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 1000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 65.90% (Accuracy Loss: -1.43%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 55.97% (Accuracy Loss: 8.50%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 5.5142
# Projection Robustness of Anonymized Test Embeddings: 6.1287
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ...

# %%
# Old
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_131558' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --tuning --n_clusters_tuning 1000 5000 --assign_labels_tuning 'majority' --noise_scale_tuning 0 0.25 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=majority, noise_scale=0.0):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 60.90%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 67.70%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 52.35%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=majority, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 60.90%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 61.40%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 51.06%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# ...

# %%
# Old
# !python knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240126_131558' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --tuning --n_clusters_tuning 1000 5000 --assign_labels_tuning 'centroid' 'majority' --noise_scale_tuning 0 0.25 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=centroid, noise_scale=0.0):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 60.90%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 10.40%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 10.88%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=centroid, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 60.90%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings 7.90%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings 9.49%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# ...

# %% [markdown]
# ### GAN

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 10 #25
batch_size = 64

# %%
# Train GAN on CIFAR100 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 10] | Discriminator loss: 0.3227 | Generator loss: 3.3253 | Real score: 0.9346 | Fake score: 0.1755
# Epoch [  2/ 10] | Discriminator loss: 0.0717 | Generator loss: 6.4482 | Real score: 0.9763 | Fake score: 0.0200
# Epoch [  3/ 10] | Discriminator loss: 0.0686 | Generator loss: 7.5763 | Real score: 0.9810 | Fake score: 0.0214
# Epoch [  4/ 10] | Discriminator loss: 0.0691 | Generator loss: 8.2487 | Real score: 0.9816 | Fake score: 0.0200
# Epoch [  5/ 10] | Discriminator loss: 0.0877 | Generator loss: 8.9323 | Real score: 0.9795 | Fake score: 0.0225
# Epoch [  6/ 10] | Discriminator loss: 0.1062 | Generator loss: 7.6725 | Real score: 0.9731 | Fake score: 0.0282
# Epoch [  7/ 10] | Discriminator loss: 0.1247 | Generator loss: 7.4194 | Real score: 0.9679 | Fake score: 0.0341
# Epoch [  8/ 10] | Discriminator loss: 0.1433 | Generator loss: 7.1398 | Real score: 0.9628 | Fake score: 0.0375
# ...

# %%
# Train GAN on CIFAR100 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 10] | Discriminator loss: 1.0009 | Generator loss: 0.7763 | Real score: 0.7561 | Fake score: 0.4893
# Epoch [  2/ 10] | Discriminator loss: 0.3991 | Generator loss: 1.6573 | Real score: 0.9857 | Fake score: 0.2987
# Epoch [  3/ 10] | Discriminator loss: 0.1486 | Generator loss: 3.2610 | Real score: 0.9821 | Fake score: 0.0829
# Epoch [  4/ 10] | Discriminator loss: 0.0937 | Generator loss: 4.4629 | Real score: 0.9834 | Fake score: 0.0403
# Epoch [  5/ 10] | Discriminator loss: 0.1078 | Generator loss: 5.4016 | Real score: 0.9756 | Fake score: 0.0296
# Epoch [  6/ 10] | Discriminator loss: 0.1301 | Generator loss: 5.4338 | Real score: 0.9639 | Fake score: 0.0353
# Epoch [  7/ 10] | Discriminator loss: 0.0855 | Generator loss: 5.7321 | Real score: 0.9785 | Fake score: 0.0238
# Epoch [  8/ 10] | Discriminator loss: 0.0944 | Generator loss: 6.0037 | Real score: 0.9757 | Fake score: 0.0244
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 22.59% (Accuracy Loss: 41.88%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 9.23% (Accuracy Loss: 55.24%)
# Reconstruction Error of Anonymized Train Embeddings: 0.1582
# Reconstruction Error of Anonymized Test Embeddings: 0.1382
# Variance Retention of Anonymized Train Embeddings: 0.7579
# Variance Retention of Anonymized Test Embeddings: 0.4466
# Projection Robustness of Anonymized Train Embeddings: 3.5236
# Projection Robustness of Anonymized Test Embeddings: 6.1319
# FID between Original and Anonymized Train Embeddings: 4.4239e+05
# FID between Original and Anonymized Test Embeddings: -1.8790e+09
# ...

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 25
batch_size = 64

# %%
# Train GAN on CIFAR100 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 25] | Discriminator loss: 0.3278 | Generator loss: 3.2074 | Real score: 0.9358 | Fake score: 0.1814
# Epoch [  2/ 25] | Discriminator loss: 0.0812 | Generator loss: 7.1891 | Real score: 0.9749 | Fake score: 0.0231
# Epoch [  3/ 25] | Discriminator loss: 0.0836 | Generator loss: 6.7668 | Real score: 0.9762 | Fake score: 0.0269
# Epoch [  4/ 25] | Discriminator loss: 0.1024 | Generator loss: 7.7172 | Real score: 0.9730 | Fake score: 0.0293
# Epoch [  5/ 25] | Discriminator loss: 0.1116 | Generator loss: 7.4630 | Real score: 0.9710 | Fake score: 0.0314
# Epoch [  6/ 25] | Discriminator loss: 0.1245 | Generator loss: 7.5737 | Real score: 0.9684 | Fake score: 0.0329
# Epoch [  7/ 25] | Discriminator loss: 0.1745 | Generator loss: 7.1227 | Real score: 0.9542 | Fake score: 0.0471
# Epoch [  8/ 25] | Discriminator loss: 0.1761 | Generator loss: 6.4495 | Real score: 0.9534 | Fake score: 0.0487
# ...

# %%
# Train GAN on CIFAR100 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 25] | Discriminator loss: 1.0003 | Generator loss: 0.7665 | Real score: 0.7571 | Fake score: 0.4898
# Epoch [  2/ 25] | Discriminator loss: 0.4503 | Generator loss: 1.4809 | Real score: 0.9760 | Fake score: 0.3215
# Epoch [  3/ 25] | Discriminator loss: 0.1436 | Generator loss: 2.8323 | Real score: 0.9910 | Fake score: 0.1014
# Epoch [  4/ 25] | Discriminator loss: 0.1142 | Generator loss: 4.1339 | Real score: 0.9750 | Fake score: 0.0467
# Epoch [  5/ 25] | Discriminator loss: 0.0687 | Generator loss: 4.8654 | Real score: 0.9850 | Fake score: 0.0237
# Epoch [  6/ 25] | Discriminator loss: 0.0844 | Generator loss: 5.5976 | Real score: 0.9812 | Fake score: 0.0232
# Epoch [  7/ 25] | Discriminator loss: 0.0788 | Generator loss: 5.8135 | Real score: 0.9837 | Fake score: 0.0223
# Epoch [  8/ 25] | Discriminator loss: 0.0664 | Generator loss: 6.7083 | Real score: 0.9869 | Fake score: 0.0190
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 24.13% (Accuracy Loss: 40.34%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 30.21% (Accuracy Loss: 34.26%)
# Reconstruction Error of Anonymized Train Embeddings: 0.1682
# Reconstruction Error of Anonymized Test Embeddings: 0.1542
# Variance Retention of Anonymized Train Embeddings: 0.8721
# Variance Retention of Anonymized Test Embeddings: 0.7092
# Projection Robustness of Anonymized Train Embeddings: 1.5525
# Projection Robustness of Anonymized Test Embeddings: 4.0629
# FID between Original and Anonymized Train Embeddings: 8.3976e+04
# FID between Original and Anonymized Test Embeddings: 4.4668e+11
# ...

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 50
batch_size = 64

# %%
# Train GAN on CIFAR100 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 50] | Discriminator loss: 0.2905 | Generator loss: 3.6026 | Real score: 0.9527 | Fake score: 0.1726
# Epoch [  2/ 50] | Discriminator loss: 0.0845 | Generator loss: 6.6525 | Real score: 0.9742 | Fake score: 0.0226
# Epoch [  3/ 50] | Discriminator loss: 0.1014 | Generator loss: 6.8574 | Real score: 0.9699 | Fake score: 0.0313
# Epoch [  4/ 50] | Discriminator loss: 0.1134 | Generator loss: 7.5209 | Real score: 0.9721 | Fake score: 0.0315
# Epoch [  5/ 50] | Discriminator loss: 0.1249 | Generator loss: 6.9009 | Real score: 0.9677 | Fake score: 0.0367
# Epoch [  6/ 50] | Discriminator loss: 0.1357 | Generator loss: 6.5341 | Real score: 0.9644 | Fake score: 0.0399
# Epoch [  7/ 50] | Discriminator loss: 0.1879 | Generator loss: 6.3464 | Real score: 0.9482 | Fake score: 0.0537
# Epoch [  8/ 50] | Discriminator loss: 0.2095 | Generator loss: 6.0897 | Real score: 0.9421 | Fake score: 0.0589
# ...

# %%
# Train GAN on CIFAR100 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 50] | Discriminator loss: 1.0200 | Generator loss: 0.7711 | Real score: 0.7433 | Fake score: 0.4886
# Epoch [  2/ 50] | Discriminator loss: 0.4528 | Generator loss: 1.8842 | Real score: 0.9641 | Fake score: 0.3073
# Epoch [  3/ 50] | Discriminator loss: 0.1322 | Generator loss: 3.3601 | Real score: 0.9713 | Fake score: 0.0749
# Epoch [  4/ 50] | Discriminator loss: 0.1161 | Generator loss: 4.2144 | Real score: 0.9794 | Fake score: 0.0445
# Epoch [  5/ 50] | Discriminator loss: 0.0949 | Generator loss: 5.1567 | Real score: 0.9757 | Fake score: 0.0286
# Epoch [  6/ 50] | Discriminator loss: 0.0964 | Generator loss: 5.0876 | Real score: 0.9776 | Fake score: 0.0287
# Epoch [  7/ 50] | Discriminator loss: 0.0755 | Generator loss: 5.9435 | Real score: 0.9832 | Fake score: 0.0215
# Epoch [  8/ 50] | Discriminator loss: 0.0960 | Generator loss: 6.3274 | Real score: 0.9780 | Fake score: 0.0241
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 23.16% (Accuracy Loss: 41.31%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 47.53% (Accuracy Loss: 16.94%)
# Reconstruction Error of Anonymized Train Embeddings: 0.1771
# Reconstruction Error of Anonymized Test Embeddings: 0.1562
# Variance Retention of Anonymized Train Embeddings: 0.9604
# Variance Retention of Anonymized Test Embeddings: 0.7815
# Projection Robustness of Anonymized Train Embeddings: 0.5758
# Projection Robustness of Anonymized Test Embeddings: 3.0744
# FID between Original and Anonymized Train Embeddings: 3.5718e+01
# FID between Original and Anonymized Test Embeddings: 1.1280e+04
# ...

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 100
batch_size = 64

# %%
# Train GAN on CIFAR100 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/100] | Discriminator loss: 0.3221 | Generator loss: 3.4738 | Real score: 0.9342 | Fake score: 0.1720
# Epoch [  2/100] | Discriminator loss: 0.0887 | Generator loss: 6.8081 | Real score: 0.9704 | Fake score: 0.0275
# Epoch [  3/100] | Discriminator loss: 0.0862 | Generator loss: 7.9132 | Real score: 0.9756 | Fake score: 0.0256
# Epoch [  4/100] | Discriminator loss: 0.0839 | Generator loss: 8.1326 | Real score: 0.9794 | Fake score: 0.0232
# Epoch [  5/100] | Discriminator loss: 0.1121 | Generator loss: 8.3212 | Real score: 0.9732 | Fake score: 0.0283
# Epoch [  6/100] | Discriminator loss: 0.1451 | Generator loss: 7.2507 | Real score: 0.9613 | Fake score: 0.0410
# Epoch [  7/100] | Discriminator loss: 0.1612 | Generator loss: 7.0715 | Real score: 0.9569 | Fake score: 0.0435
# Epoch [  8/100] | Discriminator loss: 0.1632 | Generator loss: 6.9781 | Real score: 0.9580 | Fake score: 0.0435
# ...

# %%
# Train GAN on CIFAR100 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar100"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_144942"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/100] | Discriminator loss: 0.9867 | Generator loss: 0.7557 | Real score: 0.7630 | Fake score: 0.4881
# Epoch [  2/100] | Discriminator loss: 0.4221 | Generator loss: 1.3799 | Real score: 0.9896 | Fake score: 0.3210
# Epoch [  3/100] | Discriminator loss: 0.1294 | Generator loss: 2.9829 | Real score: 0.9919 | Fake score: 0.0889
# Epoch [  4/100] | Discriminator loss: 0.0763 | Generator loss: 4.4838 | Real score: 0.9878 | Fake score: 0.0333
# Epoch [  5/100] | Discriminator loss: 0.0769 | Generator loss: 5.2687 | Real score: 0.9852 | Fake score: 0.0244
# Epoch [  6/100] | Discriminator loss: 0.0911 | Generator loss: 5.4421 | Real score: 0.9768 | Fake score: 0.0259
# Epoch [  7/100] | Discriminator loss: 0.0559 | Generator loss: 7.0331 | Real score: 0.9887 | Fake score: 0.0154
# Epoch [  8/100] | Discriminator loss: 0.1003 | Generator loss: 6.5055 | Real score: 0.9752 | Fake score: 0.0249
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240130_144942' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 64.47%
# (50000, 768)
# (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 24.30% (Accuracy Loss: 40.17%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 46.79% (Accuracy Loss: 17.68%)
# Reconstruction Error of Anonymized Train Embeddings: 0.1445
# Reconstruction Error of Anonymized Test Embeddings: 0.1591
# Variance Retention of Anonymized Train Embeddings: 0.6217
# Variance Retention of Anonymized Test Embeddings: 0.8372
# Projection Robustness of Anonymized Train Embeddings: 2.8610
# Projection Robustness of Anonymized Test Embeddings: 2.0581
# FID between Original and Anonymized Train Embeddings: -8.1265e+06
# FID between Original and Anonymized Test Embeddings: 1.0333e+03
# ...

# %% [markdown]
# # Anonymize DINOv2 embeddings

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.5 1 1.5 2 2.5 3
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 98.70%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 98.66%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 98.79%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.0): 98.46%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.5): 97.97%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.0): 96.06%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.5): 90.67%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=3.0): 81.32%
# Figure(1200x600)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240205_171500' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 5 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 18.31%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 18.31% (Accuracy Loss: 0.00%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 18.31% (Accuracy Loss: 0.00%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0000
# Reconstruction Error of Anonymized Test Embeddings: 0.0000
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 0.0000
# Projection Robustness of Anonymized Test Embeddings: 0.0000
# Overlaps between Original and Anonymized Train Embeddings: 10000
# Overlaps between Original and Anonymized Test Embeddings: 10000
# ...

# %%
# !python knn/knn_classification_anonymized.py --num_classes 100 --cp_datetime '20240205_171500' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 5000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.25%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 81.32% (Accuracy Loss: 7.93%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.31% (Accuracy Loss: 1.94%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 12.4000
# Projection Robustness of Anonymized Test Embeddings: 1.9146
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ...
