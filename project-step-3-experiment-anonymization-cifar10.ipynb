# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/xAI-project-computer-vision

import sys
sys.path.insert(0,'/content/drive/My Drive/Github/xAI-project-computer-vision')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Github/xAI-project-computer-vision

# %%
# !pip install torchinfo

# %%
import numpy as np
import random
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import datasets

print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.1.0+cu121
# torchvision version: 0.16.0+cu121

# %%
import models
from utils import print_model_summary, get_available_device, move_to_device, seed_all

device = get_available_device()
print("Device:", device)

seed_all(42)
# Out:
# Device: cuda
#
# Device: cuda
# Random seed 42 has been set.

# %% [markdown]
# # Anonymize embeddings extracted using simple custom CNNs

# %% [markdown]
# ## Simple custom CNN v1

# %% [markdown]
# ## Simple custom CNN v2

# %% [markdown]
# # Anonymize embeddings extracted using deeper custom CNNs (based on ResNet)

# %% [markdown]
# ## Simplified custom ResNet

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_012640' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'random' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 81.22%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 81.15%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.25): 81.16%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 80.68%
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.75): 78.90%
# Figure(640x480)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_012640' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'pca' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 68.15%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_014705' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 86.09%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 86.20%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.25): 84.65%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 77.45%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.75): 65.47%
# Figure(1200x600)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %% [markdown]
# ## Custom ResNet18

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'random' --noise_scale 0.75 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 79.43%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 86.01%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 86.01%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 87.80%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gaussian' --noise_scale 0.75 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 78.43%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 10 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 72.11%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 73.49%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 2 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 49.52%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 10 --anonym_method 'pca' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 73.57%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_022231' --optim_code '_1359' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 500 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 73.49%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %% [markdown]
# # Anonymize DINOv2 embeddings

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'laplace' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set: 98.66%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.5 1 1.5 2 2.5 3
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 98.70%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 98.66%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 98.79%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.0): 98.46%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.5): 97.97%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.0): 96.06%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.5): 90.67%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=3.0): 81.32%
# Figure(1200x600)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.
