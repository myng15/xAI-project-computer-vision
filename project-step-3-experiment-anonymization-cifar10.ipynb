# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/xAI-project-computer-vision

import sys
sys.path.insert(0,'/content/drive/My Drive/Github/xAI-project-computer-vision')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github/xAI-project-computer-vision

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import numpy as np
import random
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import datasets

print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.1.0+cu121
# torchvision version: 0.16.0+cu121

# %%
import models
from utils import print_model_summary, get_available_device, move_to_device, seed_all

device = get_available_device()
print("Device:", device)

seed_all(42)
# Out:
# Device: cuda
#
# Device: cuda
# Random seed 42 has been set.

# %% [markdown]
# # Anonymize embeddings extracted using simple custom CNNs

# %% [markdown]
# ## Simple custom CNN v1

# %% [markdown]
# ## Simple custom CNN v2

# %% [markdown]
# # Anonymize embeddings extracted using deeper custom CNNs (based on ResNet)

# %% [markdown]
# ## Simplified custom ResNet

# %% [markdown]
# #### PCA

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240203_002421' --optim_code '_135i' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'pca' --n_components 10 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.39%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 78.55% (Accuracy Loss: 10.84%)
# Projection Robustness of Anonymized Train Embeddings: 0.1378
# Projection Robustness of Anonymized Test Embeddings: 0.1381
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240203_002421' --optim_code '_135i' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'pca' --n_components 10 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.39%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 78.56% (Accuracy Loss: 10.83%)
# Variance Retention of Anonymized Train Embeddings: 0.9901
# Variance Retention of Anonymized Test Embeddings: 0.9900
# Projection Robustness of Anonymized Train Embeddings: 0.1378
# Projection Robustness of Anonymized Test Embeddings: 0.1381
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# ### Laplace

# %%
# !python knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_014705' --optim_code '_1359' --model_name 'resnet_custom_simplified' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 86.09%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 86.20%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.25): 84.65%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 77.45%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.75): 65.47%
# Figure(1200x600)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %% [markdown]
# ## Custom ResNet18

# %% [markdown]
# ### Laplace

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.70% (Accuracy Loss: 0.21%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.96% (Accuracy Loss: -0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0200
# Reconstruction Error of Anonymized Test Embeddings: 0.0200
# Variance Retention of Anonymized Train Embeddings: 1.3753
# Variance Retention of Anonymized Test Embeddings: 1.3820
# Projection Robustness of Anonymized Train Embeddings: 1.8240
# Projection Robustness of Anonymized Test Embeddings: 1.8420
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 1.0 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 42.77% (Accuracy Loss: 47.14%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 67.11% (Accuracy Loss: 22.80%)
# Reconstruction Error of Anonymized Train Embeddings: 1.9996
# Reconstruction Error of Anonymized Test Embeddings: 2.0035
# Variance Retention of Anonymized Train Embeddings: 38.5363
# Variance Retention of Anonymized Test Embeddings: 39.2428
# Projection Robustness of Anonymized Train Embeddings: 47.8996
# Projection Robustness of Anonymized Test Embeddings: 48.0131
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 79.51% (Accuracy Loss: 10.40%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.13% (Accuracy Loss: 2.78%)
# Reconstruction Error of Anonymized Train Embeddings: 0.4999
# Reconstruction Error of Anonymized Test Embeddings: 0.5009
# Variance Retention of Anonymized Train Embeddings: 10.3839
# Variance Retention of Anonymized Test Embeddings: 10.5595
# Projection Robustness of Anonymized Train Embeddings: 20.8252
# Projection Robustness of Anonymized Test Embeddings: 20.9068
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.25 0.5 0.75 1.0
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.1):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.70% (Accuracy Loss: 0.21%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.96% (Accuracy Loss: -0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0200
# Reconstruction Error of Anonymized Test Embeddings: 0.0200
# Variance Retention of Anonymized Train Embeddings: 1.3753
# Variance Retention of Anonymized Test Embeddings: 1.3820
# Projection Robustness of Anonymized Train Embeddings: 1.8240
# Projection Robustness of Anonymized Test Embeddings: 1.8420
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.65% (Accuracy Loss: 2.26%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.12% (Accuracy Loss: 0.79%)
# Reconstruction Error of Anonymized Train Embeddings: 0.1250
# Reconstruction Error of Anonymized Test Embeddings: 0.1249
# Variance Retention of Anonymized Train Embeddings: 3.3470
# Variance Retention of Anonymized Test Embeddings: 3.3830
# Projection Robustness of Anonymized Train Embeddings: 8.0699
# Projection Robustness of Anonymized Test Embeddings: 8.1062
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 79.39% (Accuracy Loss: 10.52%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.09% (Accuracy Loss: 2.82%)
# Reconstruction Error of Anonymized Train Embeddings: 0.4999
# Reconstruction Error of Anonymized Test Embeddings: 0.4997
# Variance Retention of Anonymized Train Embeddings: 10.3843
# Variance Retention of Anonymized Test Embeddings: 10.5414
# Projection Robustness of Anonymized Train Embeddings: 20.8235
# Projection Robustness of Anonymized Test Embeddings: 20.8813
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 60.41% (Accuracy Loss: 29.50%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 66.35% (Accuracy Loss: 23.56%)
# Reconstruction Error of Anonymized Train Embeddings: 1.1243
# Reconstruction Error of Anonymized Test Embeddings: 1.1256
# Variance Retention of Anonymized Train Embeddings: 22.1032
# Variance Retention of Anonymized Test Embeddings: 22.4847
# Projection Robustness of Anonymized Train Embeddings: 34.2498
# Projection Robustness of Anonymized Test Embeddings: 34.3382
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (noise_scale=1.0):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 40.48% (Accuracy Loss: 49.43%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 36.71% (Accuracy Loss: 53.20%)
# Reconstruction Error of Anonymized Train Embeddings: 1.9989
# Reconstruction Error of Anonymized Test Embeddings: 2.0021
# Variance Retention of Anonymized Train Embeddings: 38.5214
# Variance Retention of Anonymized Test Embeddings: 39.2200
# Projection Robustness of Anonymized Train Embeddings: 47.8853
# Projection Robustness of Anonymized Test Embeddings: 47.9969
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Reconstruction Error Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings vs. Reconstruction Error Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)

# %% [markdown]
# ### Gaussian

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gaussian' --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.56% (Accuracy Loss: 0.05%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.71% (Accuracy Loss: -0.10%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1871
# Variance Retention of Anonymized Test Embeddings: 1.1910
# Projection Robustness of Anonymized Train Embeddings: 0.9752
# Projection Robustness of Anonymized Test Embeddings: 0.9857
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# ### PCA

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 2 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 2)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 56.88% (Accuracy Loss: 33.03%)
# Variance Retention of Anonymized Train Embeddings: 0.3937
# Variance Retention of Anonymized Test Embeddings: 0.3986
# Projection Robustness of Anonymized Train Embeddings: 3.3944
# Projection Robustness of Anonymized Test Embeddings: 3.3220
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 10
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.86% (Accuracy Loss: 0.05%)
# Variance Retention of Anonymized Train Embeddings: 0.9979
# Variance Retention of Anonymized Test Embeddings: 0.9979
# Projection Robustness of Anonymized Train Embeddings: 0.0102
# Projection Robustness of Anonymized Test Embeddings: 0.0103
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 10 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.86% (Accuracy Loss: 0.05%)
# Variance Retention of Anonymized Train Embeddings: 0.9979
# Variance Retention of Anonymized Test Embeddings: 0.9979
# Projection Robustness of Anonymized Train Embeddings: 0.0102
# Projection Robustness of Anonymized Test Embeddings: 0.0103
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --n_components 50 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# (50000, 768)
# (50000,)
# (50000, 50)
# (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.94% (Accuracy Loss: -0.03%)
# Variance Retention of Anonymized Train Embeddings: 0.9999
# Variance Retention of Anonymized Test Embeddings: 0.9999
# Projection Robustness of Anonymized Train Embeddings: 0.0003
# Projection Robustness of Anonymized Test Embeddings: 0.0003
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --tuning --n_components_tuning 2 5 10 100
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=2):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 2)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 56.88% (Accuracy Loss: 33.03%)
# Variance Retention of Anonymized Train Embeddings: 0.3937
# Variance Retention of Anonymized Test Embeddings: 0.3986
# Projection Robustness of Anonymized Train Embeddings: 3.3944
# Projection Robustness of Anonymized Test Embeddings: 3.3220
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=10):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 10)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.86% (Accuracy Loss: 0.05%)
# Variance Retention of Anonymized Train Embeddings: 0.9979
# Variance Retention of Anonymized Test Embeddings: 0.9979
# Projection Robustness of Anonymized Train Embeddings: 0.0102
# Projection Robustness of Anonymized Test Embeddings: 0.0103
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=50):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 50)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.94% (Accuracy Loss: -0.03%)
# Variance Retention of Anonymized Train Embeddings: 0.9999
# Variance Retention of Anonymized Test Embeddings: 0.9999
# Projection Robustness of Anonymized Train Embeddings: 0.0003
# Projection Robustness of Anonymized Test Embeddings: 0.0003
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=100):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 100)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.96% (Accuracy Loss: -0.05%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 0.0000
# Projection Robustness of Anonymized Test Embeddings: 0.0000
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# This anonymization method does not support the reconstruction error metrics.
# This anonymization method does not support the reconstruction error metrics.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Figure(1200x600)
# Figure(1200x600)
# This anonymization method does not support visualizing accuracy loss on Original Test Embeddings vs. variance retention.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)
# Figure(1200x600)
# This anonymization method does not support visualizing accuracy loss on Original Test Embeddings vs. projection robustness.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'pca' --tuning --n_components_tuning 2 3 5 10 100
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=2):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 2)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 56.88% (Accuracy Loss: 33.03%)
# Variance Retention of Anonymized Train Embeddings: 0.3937
# Variance Retention of Anonymized Test Embeddings: 0.3986
# Projection Robustness of Anonymized Train Embeddings: 3.3944
# Projection Robustness of Anonymized Test Embeddings: 3.3220
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=3):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 3)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 78.91% (Accuracy Loss: 11.00%)
# Variance Retention of Anonymized Train Embeddings: 0.5335
# Variance Retention of Anonymized Test Embeddings: 0.5373
# Projection Robustness of Anonymized Train Embeddings: 2.3851
# Projection Robustness of Anonymized Test Embeddings: 2.3469
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 5)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 86.65% (Accuracy Loss: 3.26%)
# Variance Retention of Anonymized Train Embeddings: 0.7334
# Variance Retention of Anonymized Test Embeddings: 0.7349
# Projection Robustness of Anonymized Train Embeddings: 1.2703
# Projection Robustness of Anonymized Test Embeddings: 1.2510
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=10):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 10)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.86% (Accuracy Loss: 0.05%)
# Variance Retention of Anonymized Train Embeddings: 0.9979
# Variance Retention of Anonymized Test Embeddings: 0.9979
# Projection Robustness of Anonymized Train Embeddings: 0.0102
# Projection Robustness of Anonymized Test Embeddings: 0.0103
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_components=100):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# train_embeddings shape:  (50000, 768)
# train_labels shape:  (50000,)
# train_embeddings_anonymized shape:  (50000, 100)
# train_labels_anonymized shape:  (50000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.96% (Accuracy Loss: -0.05%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 0.0000
# Projection Robustness of Anonymized Test Embeddings: 0.0000
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# This anonymization method does not support the reconstruction error metrics.
# This anonymization method does not support the reconstruction error metrics.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Figure(1200x600)
# Figure(1200x600)
# This anonymization method does not support visualizing accuracy loss on Original Test Embeddings vs. variance retention.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)
# Figure(1200x600)
# This anonymization method does not support visualizing accuracy loss on Original Test Embeddings vs. projection robustness.

# %% [markdown]
# ### Density-based

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 3 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cpu
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 3 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cpu
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Github/xAI-project-computer-vision/knn/knn_classification_anonymized.py", line 248, in <module>
#     calculate_anonymization_metrics(train_embeddings, test_embeddings, train_labels, test_labels,
#   File "/content/drive/MyDrive/Github/xAI-project-computer-vision/anonymization/anonymization_evaluation.py", line 374, in calculate_anonymization_metrics
#     overlap_train = check_overlapping_embeddings(train_embeddings, train_embeddings_anonymized)
#   File "/content/drive/MyDrive/Github/xAI-project-computer-vision/anonymization/anonymization_evaluation.py", line 140, in check_overlapping_embeddings
#     if any(element in anonymized_embedding for element in original_embedding):
#   File "/content/drive/MyDrive/Github/xAI-project-computer-vision/anonymization/anonymization_evaluation.py", line 140, in <genexpr>
#     if any(element in anonymized_embedding for element in original_embedding):
# KeyboardInterrupt

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 3 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.94% (Accuracy Loss: 4.67%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.29% (Accuracy Loss: 1.32%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6803
# Variance Retention of Anonymized Test Embeddings: 5.7731
# Projection Robustness of Anonymized Train Embeddings: 13.1940
# Projection Robustness of Anonymized Test Embeddings: 13.2512
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 3 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.66% (Accuracy Loss: 4.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.00% (Accuracy Loss: 2.61%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6787
# Variance Retention of Anonymized Test Embeddings: 5.7724
# Projection Robustness of Anonymized Train Embeddings: 13.1909
# Projection Robustness of Anonymized Test Embeddings: 13.2499
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 5 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 5 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.66% (Accuracy Loss: 4.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.00% (Accuracy Loss: 2.61%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6787
# Variance Retention of Anonymized Test Embeddings: 5.7724
# Projection Robustness of Anonymized Train Embeddings: 13.1909
# Projection Robustness of Anonymized Test Embeddings: 13.2499
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 10 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 10 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.66% (Accuracy Loss: 4.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.00% (Accuracy Loss: 2.61%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6787
# Variance Retention of Anonymized Test Embeddings: 5.7724
# Projection Robustness of Anonymized Train Embeddings: 13.1909
# Projection Robustness of Anonymized Test Embeddings: 13.2499
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 50 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 50 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.66% (Accuracy Loss: 4.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.00% (Accuracy Loss: 2.61%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6787
# Variance Retention of Anonymized Test Embeddings: 5.7724
# Projection Robustness of Anonymized Train Embeddings: 13.1909
# Projection Robustness of Anonymized Test Embeddings: 13.2499
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 3 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.42% (Accuracy Loss: 0.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.56% (Accuracy Loss: 0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1911
# Projection Robustness of Anonymized Train Embeddings: 0.9739
# Projection Robustness of Anonymized Test Embeddings: 0.9865
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 3 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.05% (Accuracy Loss: 4.56%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.36% (Accuracy Loss: 1.25%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6788
# Variance Retention of Anonymized Test Embeddings: 5.7739
# Projection Robustness of Anonymized Train Embeddings: 13.1911
# Projection Robustness of Anonymized Test Embeddings: 13.2526
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 5 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.42% (Accuracy Loss: 0.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.56% (Accuracy Loss: 0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1911
# Projection Robustness of Anonymized Train Embeddings: 0.9739
# Projection Robustness of Anonymized Test Embeddings: 0.9865
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 5 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.05% (Accuracy Loss: 4.56%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.36% (Accuracy Loss: 1.25%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6788
# Variance Retention of Anonymized Test Embeddings: 5.7739
# Projection Robustness of Anonymized Train Embeddings: 13.1911
# Projection Robustness of Anonymized Test Embeddings: 13.2526
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 10 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.42% (Accuracy Loss: 0.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.56% (Accuracy Loss: 0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1911
# Projection Robustness of Anonymized Train Embeddings: 0.9739
# Projection Robustness of Anonymized Test Embeddings: 0.9865
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 10 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.05% (Accuracy Loss: 4.56%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.36% (Accuracy Loss: 1.25%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6788
# Variance Retention of Anonymized Test Embeddings: 5.7739
# Projection Robustness of Anonymized Train Embeddings: 13.1911
# Projection Robustness of Anonymized Test Embeddings: 13.2526
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 50 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.42% (Accuracy Loss: 0.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.56% (Accuracy Loss: 0.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1911
# Projection Robustness of Anonymized Train Embeddings: 0.9739
# Projection Robustness of Anonymized Test Embeddings: 0.9865
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 50 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.05% (Accuracy Loss: 4.56%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.36% (Accuracy Loss: 1.25%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6788
# Variance Retention of Anonymized Test Embeddings: 5.7739
# Projection Robustness of Anonymized Train Embeddings: 13.1911
# Projection Robustness of Anonymized Test Embeddings: 13.2526
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 3 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 3 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.93% (Accuracy Loss: 4.68%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.37% (Accuracy Loss: 2.24%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6806
# Variance Retention of Anonymized Test Embeddings: 5.7758
# Projection Robustness of Anonymized Train Embeddings: 13.1943
# Projection Robustness of Anonymized Test Embeddings: 13.2564
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 5 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 5 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.93% (Accuracy Loss: 4.68%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.37% (Accuracy Loss: 2.24%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6806
# Variance Retention of Anonymized Test Embeddings: 5.7758
# Projection Robustness of Anonymized Train Embeddings: 13.1943
# Projection Robustness of Anonymized Test Embeddings: 13.2564
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 10 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 10 --noise_scale 0.5
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.93% (Accuracy Loss: 4.68%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.37% (Accuracy Loss: 2.24%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6806
# Variance Retention of Anonymized Test Embeddings: 5.7758
# Projection Robustness of Anonymized Train Embeddings: 13.1943
# Projection Robustness of Anonymized Test Embeddings: 13.2564
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 50 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 50 --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.93% (Accuracy Loss: 4.68%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.37% (Accuracy Loss: 2.24%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6806
# Variance Retention of Anonymized Test Embeddings: 5.7758
# Projection Robustness of Anonymized Train Embeddings: 13.1943
# Projection Robustness of Anonymized Test Embeddings: 13.2564
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 8 --min_samples 5 --noise_scale 0.0 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.61% (Accuracy Loss: 0.00%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.61% (Accuracy Loss: 0.00%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0000
# Reconstruction Error of Anonymized Test Embeddings: 0.0000
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 0.0000
# Projection Robustness of Anonymized Test Embeddings: 0.0000
# Overlaps between Original and Anonymized Train Embeddings: 10000
# Overlaps between Original and Anonymized Test Embeddings: 10000
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 6 --min_samples 3 --noise_scale 0.1
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.62% (Accuracy Loss: -0.01%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.87% (Accuracy Loss: -0.26%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1873
# Variance Retention of Anonymized Test Embeddings: 1.1911
# Projection Robustness of Anonymized Train Embeddings: 0.9760
# Projection Robustness of Anonymized Test Embeddings: 0.9864
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 10 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 15 --min_samples 5 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.52% (Accuracy Loss: 0.09%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.48% (Accuracy Loss: 0.13%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1873
# Variance Retention of Anonymized Test Embeddings: 1.1910
# Projection Robustness of Anonymized Train Embeddings: 0.9762
# Projection Robustness of Anonymized Test Embeddings: 0.9858
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 20 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 10 --min_samples 50 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.57% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1872
# Variance Retention of Anonymized Test Embeddings: 1.1915
# Projection Robustness of Anonymized Train Embeddings: 0.9753
# Projection Robustness of Anonymized Test Embeddings: 0.9882
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 3 --min_samples 20 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.64% (Accuracy Loss: -0.03%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.69% (Accuracy Loss: -0.08%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1859
# Variance Retention of Anonymized Test Embeddings: 1.1902
# Projection Robustness of Anonymized Train Embeddings: 0.9702
# Projection Robustness of Anonymized Test Embeddings: 0.9823
# Overlaps between Original and Anonymized Train Embeddings: 44
# Overlaps between Original and Anonymized Test Embeddings: 50
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 3 --min_samples 50 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.30% (Accuracy Loss: 0.31%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.60% (Accuracy Loss: 0.01%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0099
# Reconstruction Error of Anonymized Test Embeddings: 0.0099
# Variance Retention of Anonymized Train Embeddings: 1.1848
# Variance Retention of Anonymized Test Embeddings: 1.1881
# Projection Robustness of Anonymized Train Embeddings: 0.9651
# Projection Robustness of Anonymized Test Embeddings: 0.9731
# Overlaps between Original and Anonymized Train Embeddings: 133
# Overlaps between Original and Anonymized Test Embeddings: 144
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 30 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.55% (Accuracy Loss: 0.06%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.50% (Accuracy Loss: 0.11%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1868
# Variance Retention of Anonymized Test Embeddings: 1.1908
# Projection Robustness of Anonymized Train Embeddings: 0.9737
# Projection Robustness of Anonymized Test Embeddings: 0.9852
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 15 --min_samples 50 --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 89.52% (Accuracy Loss: 0.09%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.48% (Accuracy Loss: 0.13%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0100
# Reconstruction Error of Anonymized Test Embeddings: 0.0100
# Variance Retention of Anonymized Train Embeddings: 1.1873
# Variance Retention of Anonymized Test Embeddings: 1.1910
# Projection Robustness of Anonymized Train Embeddings: 0.9762
# Projection Robustness of Anonymized Test Embeddings: 0.9858
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 5 --min_samples 50 --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# [[ 0.24835708 -0.06913215  0.32384427 ... -0.35158821 -0.01749425
#    0.88540032]
#  [-0.31348353  0.90622428  0.35387597 ... -0.07380129 -0.23301825
#   -0.79735153]
#  [ 0.25680005 -0.26635042 -0.58495842 ... -0.49903031 -0.19198564
#    0.1251001 ]
#  ...
#  [-0.27464707  0.06084446 -0.35406518 ...  0.45930372  0.93061397
#   -0.04199514]
#  [ 0.14700222 -1.26974484  0.32592035 ... -0.69306722  0.04593511
#   -0.1903189 ]
#  [-0.77996102 -1.16670438 -0.29287569 ...  0.09808834 -0.71644558
#    0.0440297 ]]
# [[-0.3713598  -0.09531578  0.56384722 ... -0.25961912 -0.20901498
#   -0.29727752]
#  [ 0.59811831 -0.04164935  1.23147147 ... -0.34068223  0.79709164
#   -0.27907915]
#  [ 0.26598899 -0.13271387  0.14259418 ... -1.034766    0.32674979
#   -0.4296411 ]
#  ...
#  [-0.46727459 -0.3352979  -0.46334917 ...  0.07938816  0.10611098
#   -1.07545759]
#  [-0.21946101 -0.925559   -0.38135201 ... -0.07372742  0.36279775
#    0.26874219]
#  [-0.27928763  0.04978863  0.15863775 ...  0.08320071  1.32544447
#    0.18197181]]
# [[-0.89340786 -0.65735206 -0.21881342 ... -0.5846157  -0.49307748
#    0.29434226]
#  [-0.40754982 -0.3780418   1.04878825 ... -0.74428873 -0.65652571
#    0.42006332]
#  [ 0.12053624 -0.76944062 -0.6828971  ...  0.19466582  0.75912992
#    0.42477422]
#  ...
#  [ 0.60195382  0.33429476 -0.06215065 ...  0.12302072  0.09517048
#    0.60640059]
#  [ 0.6310758  -0.55181965  0.14769091 ... -0.39417868 -0.51462869
#   -0.5138512 ]
#  [ 1.46611274 -0.5720674   0.46989802 ... -0.68086337 -0.06535726
#   -0.43087197]]
# [[-0.51404772  0.37599487  0.86761164 ... -0.10926044 -0.43588159
#   -0.55327093]
#  [ 0.23839761  0.46961989  0.15831275 ...  0.36905705  0.08858425
#    0.32014821]
#  [ 0.44056302 -0.12482509 -0.47153638 ... -0.05201105 -0.68043608
#   -0.66679643]
#  ...
#  [ 1.02184988  1.03399845 -0.03487274 ... -0.06573076 -0.33787877
#    1.06398333]
#  [ 0.98418723 -0.01691678 -0.13018698 ...  0.0227401  -1.04487895
#    0.30969424]
#  [ 0.65399701 -0.61442027  0.39433707 ... -0.31011833  1.82297928
#    0.19084771]]
# [[-0.33776114 -0.47235045  0.05856988 ... -1.03222518 -0.92723869
#   -0.0559964 ]
#  [-0.79019861 -0.38088497 -0.30311735 ...  0.88280871  0.1751408
#   -0.41019699]
#  [-0.23546157  0.32511105 -0.76201661 ...  0.3991022  -0.34878282
#    0.4009911 ]
#  ...
#  [ 0.42451854  0.03346838  0.51996697 ...  0.71182263  0.82540234
#   -0.05128765]
#  [ 0.03371438 -1.46214936  0.21436545 ...  0.80879358 -0.55356956
#   -0.20512587]
#  [ 0.22936709 -0.6018624   0.16125601 ...  0.35882625 -0.375643
#   -0.43413542]]
# [[ 0.4160916  -0.55866196 -0.26374832 ...  0.16033576  0.34995702
#    0.13577921]
#  [ 0.13846369  0.25289193 -0.71678498 ...  1.12707411 -1.25562922
#    0.4368092 ]
#  [ 0.31243754 -0.9771757  -0.1560726  ... -0.26889324 -0.42894844
#    0.46888874]
#  ...
#  [-1.04586535  0.3185078   0.54996471 ... -0.66922698  0.07925584
#   -0.43445666]
#  [ 0.194262    0.18084002  0.30598732 ... -0.85661489 -0.31990191
#   -0.15940553]
#  [ 0.76860228 -0.02474537  0.50770065 ...  0.08938633 -0.23778329
#    0.0749984 ]]
# [[-0.20093654  0.1096839   0.83133299 ...  0.63394981  0.49939896
#   -0.15974582]
#  [ 0.12499873  0.66391962  0.54680673 ... -0.19670302  0.04269112
#   -0.53060304]
#  [-0.33307437 -0.01865003 -0.66519343 ... -0.67412491  0.05696615
#   -0.6113352 ]
#  ...
#  [-0.15562715 -0.79938803  0.18038579 ...  0.06650544  0.28707446
#   -0.13726529]
#  [ 0.40369538 -0.22197066  0.74338159 ... -0.15297218  0.45698586
#    0.33744586]
#  [ 0.55246111 -1.25643106  0.25246283 ... -0.92113542  0.50534645
#    0.19627765]]
# [[-0.47575554  0.59150333 -0.39061371 ...  0.02824009  0.49850422
#    0.01154591]
#  [-0.46421282 -1.1826407   0.31276495 ... -0.44053729  0.92251089
#    0.83138836]
#  [ 1.35078394  0.48252842  0.23379733 ... -0.33786403 -0.01960327
#    0.40877159]
#  ...
#  [-0.09302311 -0.40002142  0.08012301 ...  0.36976154 -0.27174295
#    0.18845521]
#  [-0.31352772 -0.32249498  1.02036144 ... -0.24527132  0.50730965
#   -0.22936165]
#  [-0.06267295  0.61894656 -0.12383169 ...  0.24064291 -0.54609001
#   -0.31466758]]
# [[-0.50199133  0.45720951 -0.22453848 ... -1.11716745 -0.03208305
#   -0.07549534]
#  [ 0.50835337 -0.62267975 -0.262952   ...  0.23125043  0.12246231
#    0.17887983]
#  [ 0.35386346 -0.54704115  0.33875845 ... -0.03686237  0.69625409
#    0.01198633]
#  ...
#  [ 0.28683052  0.01214292 -0.07586527 ...  0.05616372 -0.88462005
#    0.49583426]
#  [ 0.22969304 -0.45231885  0.84239396 ...  0.50024155  0.40983473
#    0.65049285]
#  [ 0.61687992 -0.67204261  0.18014824 ...  0.16522705  0.85977819
#   -0.98136281]]
# [[-0.16847703  0.30869165  0.10843037 ... -0.41894566  0.35109423
#   -1.09850639]
#  [ 0.11331827  0.20095312  0.6126881  ... -1.15164903 -0.78123427
#   -0.82091852]
#  [ 0.48860935  0.26388986 -0.38069637 ...  0.12776952  0.03465498
#   -0.70577695]
#  ...
#  [ 0.24498026 -0.41553633 -0.01955705 ... -0.29806556  0.49457972
#   -0.16242718]
#  [ 0.20798301  0.41120334 -0.40576573 ...  0.77993086  0.85681711
#   -0.20423764]
#  [-1.14284919  0.2319105  -0.07856496 ...  0.17992191  0.55355742
#    0.40439994]]
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.66% (Accuracy Loss: 4.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.00% (Accuracy Loss: 2.61%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6787
# Variance Retention of Anonymized Test Embeddings: 5.7724
# Projection Robustness of Anonymized Train Embeddings: 13.1909
# Projection Robustness of Anonymized Test Embeddings: 13.2499
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'density_based' --max_dist 15 --min_samples 50 --noise_scale 0.5 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.61%
# train_embeddings shape:  (10000, 768)
# train_labels shape:  (10000,)
# train_embeddings_anonymized shape:  (10000, 768)
# train_labels_anonymized shape:  (10000,)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 84.87% (Accuracy Loss: 4.74%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.56% (Accuracy Loss: 1.05%)
# Reconstruction Error of Anonymized Train Embeddings: 0.2501
# Reconstruction Error of Anonymized Test Embeddings: 0.2500
# Variance Retention of Anonymized Train Embeddings: 5.6814
# Variance Retention of Anonymized Test Embeddings: 5.7732
# Projection Robustness of Anonymized Train Embeddings: 13.1960
# Projection Robustness of Anonymized Test Embeddings: 13.2515
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# ### K-Means

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 1000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 90.10% (Accuracy Loss: -0.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.99% (Accuracy Loss: 1.92%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9181
# Projection Robustness of Anonymized Test Embeddings: 8.0313
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 1000 --assign_labels 'centroid' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 74.90% (Accuracy Loss: 15.01%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 85.47% (Accuracy Loss: 4.44%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9180
# Projection Robustness of Anonymized Test Embeddings: 8.0313
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 5000 --assign_labels 'centroid' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 81.00% (Accuracy Loss: 8.91%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 86.99% (Accuracy Loss: 2.92%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9875
# Projection Robustness of Anonymized Test Embeddings: 8.0756
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 5000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.24% (Accuracy Loss: 4.67%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.45% (Accuracy Loss: 1.46%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9875
# Projection Robustness of Anonymized Test Embeddings: 8.0756
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --tuning --n_clusters_tuning 1000 2500 5000 --assign_labels_tuning 'centroid' 'majority' --noise_scale_tuning 0.25 0.5 0.75
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=centroid, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 74.90% (Accuracy Loss: 15.01%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 85.47% (Accuracy Loss: 4.44%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9181
# Projection Robustness of Anonymized Test Embeddings: 8.0313
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=centroid, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 63.40% (Accuracy Loss: 26.51%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 76.60% (Accuracy Loss: 13.31%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7523
# Projection Robustness of Anonymized Test Embeddings: 20.8237
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=centroid, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 39.50% (Accuracy Loss: 50.41%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 44.16% (Accuracy Loss: 45.75%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.2193
# Projection Robustness of Anonymized Test Embeddings: 34.3038
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=majority, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 88.50% (Accuracy Loss: 1.41%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.20% (Accuracy Loss: 1.71%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.8870
# Projection Robustness of Anonymized Test Embeddings: 8.0053
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=majority, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 68.10% (Accuracy Loss: 21.81%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 74.45% (Accuracy Loss: 15.46%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7555
# Projection Robustness of Anonymized Test Embeddings: 20.8030
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=1000, assign_labels=majority, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 46.10% (Accuracy Loss: 43.81%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 51.77% (Accuracy Loss: 38.14%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.2442
# Projection Robustness of Anonymized Test Embeddings: 34.2791
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=centroid, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 76.72% (Accuracy Loss: 13.19%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 84.91% (Accuracy Loss: 5.00%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9359
# Projection Robustness of Anonymized Test Embeddings: 8.0325
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=centroid, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 64.52% (Accuracy Loss: 25.39%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 80.60% (Accuracy Loss: 9.31%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7402
# Projection Robustness of Anonymized Test Embeddings: 20.9137
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=centroid, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 40.00% (Accuracy Loss: 49.91%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 53.22% (Accuracy Loss: 36.69%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.1505
# Projection Robustness of Anonymized Test Embeddings: 34.2555
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=majority, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 86.40% (Accuracy Loss: 3.51%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.59% (Accuracy Loss: 2.32%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9416
# Projection Robustness of Anonymized Test Embeddings: 8.0839
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=majority, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 70.96% (Accuracy Loss: 18.95%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 71.06% (Accuracy Loss: 18.85%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7474
# Projection Robustness of Anonymized Test Embeddings: 20.8753
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=2500, assign_labels=majority, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 50.84% (Accuracy Loss: 39.07%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 66.70% (Accuracy Loss: 23.21%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.1931
# Projection Robustness of Anonymized Test Embeddings: 34.3134
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'kmeans' --tuning --n_clusters_tuning 5000 --assign_labels_tuning 'centroid' 'majority' --noise_scale_tuning 0.25 0.5 0.75
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=centroid, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 81.00% (Accuracy Loss: 8.91%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 86.99% (Accuracy Loss: 2.92%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9874
# Projection Robustness of Anonymized Test Embeddings: 8.0756
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=centroid, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 70.04% (Accuracy Loss: 19.87%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 82.76% (Accuracy Loss: 7.15%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7626
# Projection Robustness of Anonymized Test Embeddings: 20.8576
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=centroid, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 48.26% (Accuracy Loss: 41.65%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 70.92% (Accuracy Loss: 18.99%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.2026
# Projection Robustness of Anonymized Test Embeddings: 34.3077
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=majority, noise_scale=0.25):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 85.42% (Accuracy Loss: 4.49%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 88.70% (Accuracy Loss: 1.21%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 7.9882
# Projection Robustness of Anonymized Test Embeddings: 8.0824
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=majority, noise_scale=0.5):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 71.32% (Accuracy Loss: 18.59%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 79.93% (Accuracy Loss: 9.98%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 20.7742
# Projection Robustness of Anonymized Test Embeddings: 20.8563
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# Performance Metrics (n_clusters=5000, assign_labels=majority, noise_scale=0.75):
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 53.60% (Accuracy Loss: 36.31%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 66.91% (Accuracy Loss: 23.00%)
# Variance Retention of Anonymized Train Embeddings: 1.0000
# Variance Retention of Anonymized Test Embeddings: 1.0000
# Projection Robustness of Anonymized Train Embeddings: 34.2349
# Projection Robustness of Anonymized Test Embeddings: 34.3809
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# This anonymization method does not support the reconstruction error metrics.
# This anonymization method does not support the reconstruction error metrics.
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Figure(1200x600)
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings vs. Variance Retention Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)
# Plot of KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings vs. Projection Robustness Saved.
# Figure(1200x600)

# %% [markdown]
# ### GAN

# %% [markdown]
# #### 10 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 10 #25
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 10] | Discriminator loss: 0.4025 | Generator loss: 2.6273 | Real score: 0.9127 | Fake score: 0.2054
# Epoch [  2/ 10] | Discriminator loss: 0.2746 | Generator loss: 4.5443 | Real score: 0.9129 | Fake score: 0.0769
# Epoch [  3/ 10] | Discriminator loss: 0.4178 | Generator loss: 3.8340 | Real score: 0.8650 | Fake score: 0.1318
# Epoch [  4/ 10] | Discriminator loss: 0.5015 | Generator loss: 3.5543 | Real score: 0.8400 | Fake score: 0.1624
# Epoch [  5/ 10] | Discriminator loss: 0.6258 | Generator loss: 2.7273 | Real score: 0.7941 | Fake score: 0.2070
# Epoch [  6/ 10] | Discriminator loss: 0.7622 | Generator loss: 2.2663 | Real score: 0.7516 | Fake score: 0.2504
# Epoch [  7/ 10] | Discriminator loss: 0.8768 | Generator loss: 1.8831 | Real score: 0.7073 | Fake score: 0.2964
# Epoch [  8/ 10] | Discriminator loss: 0.9579 | Generator loss: 1.6415 | Real score: 0.6747 | Fake score: 0.3248
# Epoch [  9/ 10] | Discriminator loss: 1.0186 | Generator loss: 1.4846 | Real score: 0.6512 | Fake score: 0.3496
# Epoch [ 10/ 10] | Discriminator loss: 1.0658 | Generator loss: 1.4122 | Real score: 0.6343 | Fake score: 0.3666
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 10] | Discriminator loss: 1.1483 | Generator loss: 0.7033 | Real score: 0.6964 | Fake score: 0.5208
# Epoch [  2/ 10] | Discriminator loss: 0.8663 | Generator loss: 1.2243 | Real score: 0.8215 | Fake score: 0.4367
# Epoch [  3/ 10] | Discriminator loss: 0.3456 | Generator loss: 2.3829 | Real score: 0.9147 | Fake score: 0.1796
# Epoch [  4/ 10] | Discriminator loss: 0.2408 | Generator loss: 3.3792 | Real score: 0.9324 | Fake score: 0.0887
# Epoch [  5/ 10] | Discriminator loss: 0.3271 | Generator loss: 4.3607 | Real score: 0.9055 | Fake score: 0.0892
# Epoch [  6/ 10] | Discriminator loss: 0.3888 | Generator loss: 3.7623 | Real score: 0.8814 | Fake score: 0.1032
# Epoch [  7/ 10] | Discriminator loss: 0.2879 | Generator loss: 3.5742 | Real score: 0.9124 | Fake score: 0.0910
# Epoch [  8/ 10] | Discriminator loss: 0.3112 | Generator loss: 3.9740 | Real score: 0.9088 | Fake score: 0.0958
# Epoch [  9/ 10] | Discriminator loss: 0.3328 | Generator loss: 3.7352 | Real score: 0.8997 | Fake score: 0.1045
# Epoch [ 10/ 10] | Discriminator loss: 0.3863 | Generator loss: 3.4804 | Real score: 0.8874 | Fake score: 0.1170
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 91.66% (Accuracy Loss: -1.75%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.27% (Accuracy Loss: 0.64%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0831
# Reconstruction Error of Anonymized Test Embeddings: 0.0879
# Variance Retention of Anonymized Train Embeddings: 0.7818
# Variance Retention of Anonymized Test Embeddings: 0.8391
# Projection Robustness of Anonymized Train Embeddings: 1.5137
# Projection Robustness of Anonymized Test Embeddings: 2.8799
# FID between Original and Anonymized Train Embeddings: -1.1963e+37
# FID between Original and Anonymized Test Embeddings: 3.4074e+33
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision/visualization.py:203: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(x=test_reduced_embeddings[:, 0], y=test_reduced_embeddings[:, 1], hue=test_labels,
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 15 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 15
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 15] | Discriminator loss: 0.4025 | Generator loss: 2.6273 | Real score: 0.9127 | Fake score: 0.2054
# Epoch [  2/ 15] | Discriminator loss: 0.2746 | Generator loss: 4.5443 | Real score: 0.9129 | Fake score: 0.0769
# Epoch [  3/ 15] | Discriminator loss: 0.4178 | Generator loss: 3.8340 | Real score: 0.8650 | Fake score: 0.1318
# Epoch [  4/ 15] | Discriminator loss: 0.5015 | Generator loss: 3.5543 | Real score: 0.8400 | Fake score: 0.1624
# Epoch [  5/ 15] | Discriminator loss: 0.6258 | Generator loss: 2.7273 | Real score: 0.7941 | Fake score: 0.2070
# Epoch [  6/ 15] | Discriminator loss: 0.7622 | Generator loss: 2.2663 | Real score: 0.7516 | Fake score: 0.2504
# Epoch [  7/ 15] | Discriminator loss: 0.8768 | Generator loss: 1.8831 | Real score: 0.7073 | Fake score: 0.2964
# Epoch [  8/ 15] | Discriminator loss: 0.9579 | Generator loss: 1.6415 | Real score: 0.6747 | Fake score: 0.3248
# Epoch [  9/ 15] | Discriminator loss: 1.0186 | Generator loss: 1.4846 | Real score: 0.6512 | Fake score: 0.3496
# Epoch [ 10/ 15] | Discriminator loss: 1.0658 | Generator loss: 1.4122 | Real score: 0.6343 | Fake score: 0.3666
# Epoch [ 11/ 15] | Discriminator loss: 1.1054 | Generator loss: 1.2836 | Real score: 0.6187 | Fake score: 0.3821
# Epoch [ 12/ 15] | Discriminator loss: 1.1095 | Generator loss: 1.2403 | Real score: 0.6138 | Fake score: 0.3862
# Epoch [ 13/ 15] | Discriminator loss: 1.1471 | Generator loss: 1.2447 | Real score: 0.6031 | Fake score: 0.3963
# Epoch [ 14/ 15] | Discriminator loss: 1.1793 | Generator loss: 1.1630 | Real score: 0.5932 | Fake score: 0.4072
# Epoch [ 15/ 15] | Discriminator loss: 1.2227 | Generator loss: 1.0874 | Real score: 0.5762 | Fake score: 0.4244
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 15] | Discriminator loss: 1.1034 | Generator loss: 0.7184 | Real score: 0.7123 | Fake score: 0.5111
# Epoch [  2/ 15] | Discriminator loss: 0.4902 | Generator loss: 1.2812 | Real score: 0.9647 | Fake score: 0.3500
# Epoch [  3/ 15] | Discriminator loss: 0.1570 | Generator loss: 2.8635 | Real score: 0.9803 | Fake score: 0.0993
# Epoch [  4/ 15] | Discriminator loss: 0.2159 | Generator loss: 4.1172 | Real score: 0.9487 | Fake score: 0.0627
# Epoch [  5/ 15] | Discriminator loss: 0.1746 | Generator loss: 4.4563 | Real score: 0.9526 | Fake score: 0.0495
# Epoch [  6/ 15] | Discriminator loss: 0.2808 | Generator loss: 4.6996 | Real score: 0.9162 | Fake score: 0.0717
# Epoch [  7/ 15] | Discriminator loss: 0.2542 | Generator loss: 4.7347 | Real score: 0.9202 | Fake score: 0.0691
# Epoch [  8/ 15] | Discriminator loss: 0.2575 | Generator loss: 4.8051 | Real score: 0.9158 | Fake score: 0.0819
# Epoch [  9/ 15] | Discriminator loss: 0.2201 | Generator loss: 5.0690 | Real score: 0.9310 | Fake score: 0.0683
# Epoch [ 10/ 15] | Discriminator loss: 0.2614 | Generator loss: 5.2671 | Real score: 0.9232 | Fake score: 0.0799
# Epoch [ 11/ 15] | Discriminator loss: 0.2885 | Generator loss: 5.5208 | Real score: 0.9128 | Fake score: 0.0851
# Epoch [ 12/ 15] | Discriminator loss: 0.2418 | Generator loss: 4.5328 | Real score: 0.9223 | Fake score: 0.0773
# Epoch [ 13/ 15] | Discriminator loss: 0.3031 | Generator loss: 4.8773 | Real score: 0.9156 | Fake score: 0.0908
# Epoch [ 14/ 15] | Discriminator loss: 0.2468 | Generator loss: 4.5148 | Real score: 0.9322 | Fake score: 0.0813
# Epoch [ 15/ 15] | Discriminator loss: 0.3305 | Generator loss: 4.9808 | Real score: 0.9083 | Fake score: 0.1025
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 90.45% (Accuracy Loss: -0.54%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.79% (Accuracy Loss: 0.12%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0869
# Reconstruction Error of Anonymized Test Embeddings: 0.0828
# Variance Retention of Anonymized Train Embeddings: 0.8410
# Variance Retention of Anonymized Test Embeddings: 0.6981
# Projection Robustness of Anonymized Train Embeddings: 0.9739
# Projection Robustness of Anonymized Test Embeddings: 2.7250
# FID between Original and Anonymized Train Embeddings: -7.2692e+35
# FID between Original and Anonymized Test Embeddings: -2.6585e+37
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# /content/drive/My Drive/Github/xAI-project-computer-vision/visualization.py:203: UserWarning: The palette list has more values (10) than needed (9), which may not be intended.
#   sns.scatterplot(x=test_reduced_embeddings[:, 0], y=test_reduced_embeddings[:, 1], hue=test_labels,
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 20 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 20
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 20] | Discriminator loss: 0.4619 | Generator loss: 2.6355 | Real score: 0.8897 | Fake score: 0.2193
# Epoch [  2/ 20] | Discriminator loss: 0.2372 | Generator loss: 5.0159 | Real score: 0.9214 | Fake score: 0.0690
# Epoch [  3/ 20] | Discriminator loss: 0.3285 | Generator loss: 4.5312 | Real score: 0.8972 | Fake score: 0.1015
# Epoch [  4/ 20] | Discriminator loss: 0.4451 | Generator loss: 3.9681 | Real score: 0.8625 | Fake score: 0.1367
# Epoch [  5/ 20] | Discriminator loss: 0.5729 | Generator loss: 3.2232 | Real score: 0.8141 | Fake score: 0.1851
# Epoch [  6/ 20] | Discriminator loss: 0.7297 | Generator loss: 2.5860 | Real score: 0.7569 | Fake score: 0.2433
# Epoch [  7/ 20] | Discriminator loss: 0.9105 | Generator loss: 1.9609 | Real score: 0.6941 | Fake score: 0.3061
# Epoch [  8/ 20] | Discriminator loss: 1.0069 | Generator loss: 1.6612 | Real score: 0.6578 | Fake score: 0.3440
# Epoch [  9/ 20] | Discriminator loss: 1.0795 | Generator loss: 1.4838 | Real score: 0.6311 | Fake score: 0.3686
# Epoch [ 10/ 20] | Discriminator loss: 1.1152 | Generator loss: 1.3400 | Real score: 0.6161 | Fake score: 0.3847
# Epoch [ 11/ 20] | Discriminator loss: 1.1573 | Generator loss: 1.3059 | Real score: 0.6023 | Fake score: 0.3984
# Epoch [ 12/ 20] | Discriminator loss: 1.1932 | Generator loss: 1.2148 | Real score: 0.5899 | Fake score: 0.4118
# Epoch [ 13/ 20] | Discriminator loss: 1.2155 | Generator loss: 1.1683 | Real score: 0.5786 | Fake score: 0.4207
# Epoch [ 14/ 20] | Discriminator loss: 1.2266 | Generator loss: 1.1295 | Real score: 0.5734 | Fake score: 0.4266
# Epoch [ 15/ 20] | Discriminator loss: 1.2636 | Generator loss: 1.0443 | Real score: 0.5608 | Fake score: 0.4391
# Epoch [ 16/ 20] | Discriminator loss: 1.2887 | Generator loss: 0.9937 | Real score: 0.5494 | Fake score: 0.4501
# Epoch [ 17/ 20] | Discriminator loss: 1.3124 | Generator loss: 0.9421 | Real score: 0.5394 | Fake score: 0.4611
# Epoch [ 18/ 20] | Discriminator loss: 1.3199 | Generator loss: 0.9113 | Real score: 0.5340 | Fake score: 0.4663
# Epoch [ 19/ 20] | Discriminator loss: 1.3308 | Generator loss: 0.8971 | Real score: 0.5302 | Fake score: 0.4710
# Epoch [ 20/ 20] | Discriminator loss: 1.3371 | Generator loss: 0.8805 | Real score: 0.5269 | Fake score: 0.4739
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 20] | Discriminator loss: 1.1199 | Generator loss: 0.7056 | Real score: 0.7136 | Fake score: 0.5195
# Epoch [  2/ 20] | Discriminator loss: 0.6402 | Generator loss: 1.1208 | Real score: 0.9223 | Fake score: 0.3991
# Epoch [  3/ 20] | Discriminator loss: 0.2731 | Generator loss: 2.5039 | Real score: 0.9494 | Fake score: 0.1592
# Epoch [  4/ 20] | Discriminator loss: 0.2104 | Generator loss: 3.5486 | Real score: 0.9509 | Fake score: 0.0722
# Epoch [  5/ 20] | Discriminator loss: 0.1900 | Generator loss: 4.1904 | Real score: 0.9519 | Fake score: 0.0562
# Epoch [  6/ 20] | Discriminator loss: 0.2072 | Generator loss: 4.0176 | Real score: 0.9450 | Fake score: 0.0594
# Epoch [  7/ 20] | Discriminator loss: 0.2026 | Generator loss: 4.3039 | Real score: 0.9475 | Fake score: 0.0510
# Epoch [  8/ 20] | Discriminator loss: 0.2780 | Generator loss: 4.4959 | Real score: 0.9168 | Fake score: 0.0765
# Epoch [  9/ 20] | Discriminator loss: 0.2727 | Generator loss: 4.5955 | Real score: 0.9189 | Fake score: 0.0752
# Epoch [ 10/ 20] | Discriminator loss: 0.3537 | Generator loss: 4.6282 | Real score: 0.9046 | Fake score: 0.1082
# Epoch [ 11/ 20] | Discriminator loss: 0.3186 | Generator loss: 4.0598 | Real score: 0.8986 | Fake score: 0.0931
# Epoch [ 12/ 20] | Discriminator loss: 0.3351 | Generator loss: 4.0791 | Real score: 0.8996 | Fake score: 0.1052
# Epoch [ 13/ 20] | Discriminator loss: 0.2629 | Generator loss: 4.2608 | Real score: 0.9213 | Fake score: 0.0880
# Epoch [ 14/ 20] | Discriminator loss: 0.3855 | Generator loss: 4.1826 | Real score: 0.8882 | Fake score: 0.1184
# Epoch [ 15/ 20] | Discriminator loss: 0.4520 | Generator loss: 4.1449 | Real score: 0.8669 | Fake score: 0.1354
# Epoch [ 16/ 20] | Discriminator loss: 0.4539 | Generator loss: 4.1117 | Real score: 0.8653 | Fake score: 0.1373
# Epoch [ 18/ 20] | Discriminator loss: 0.5499 | Generator loss: 3.0930 | Real score: 0.8192 | Fake score: 0.1875
# Epoch [ 19/ 20] | Discriminator loss: 0.6034 | Generator loss: 2.8375 | Real score: 0.8015 | Fake score: 0.2030
# Epoch [ 20/ 20] | Discriminator loss: 0.6403 | Generator loss: 2.7189 | Real score: 0.7824 | Fake score: 0.2183
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 91.01% (Accuracy Loss: -1.10%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.77% (Accuracy Loss: 0.14%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0906
# Reconstruction Error of Anonymized Test Embeddings: 0.0873
# Variance Retention of Anonymized Train Embeddings: 0.9146
# Variance Retention of Anonymized Test Embeddings: 0.9015
# Projection Robustness of Anonymized Train Embeddings: 0.5239
# Projection Robustness of Anonymized Test Embeddings: 1.9680
# FID between Original and Anonymized Train Embeddings: 3.9614e+29
# FID between Original and Anonymized Test Embeddings: 1.1059e+39
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# /content/drive/My Drive/Github/xAI-project-computer-vision/visualization.py:203: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.scatterplot(x=test_reduced_embeddings[:, 0], y=test_reduced_embeddings[:, 1], hue=test_labels,
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 25 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 25
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 25] | Discriminator loss: 0.4025 | Generator loss: 2.6273 | Real score: 0.9127 | Fake score: 0.2054
# Epoch [  2/ 25] | Discriminator loss: 0.2746 | Generator loss: 4.5443 | Real score: 0.9129 | Fake score: 0.0769
# Epoch [  3/ 25] | Discriminator loss: 0.4178 | Generator loss: 3.8340 | Real score: 0.8650 | Fake score: 0.1318
# Epoch [  4/ 25] | Discriminator loss: 0.5015 | Generator loss: 3.5543 | Real score: 0.8400 | Fake score: 0.1624
# Epoch [  5/ 25] | Discriminator loss: 0.6258 | Generator loss: 2.7273 | Real score: 0.7941 | Fake score: 0.2070
# Epoch [  6/ 25] | Discriminator loss: 0.7622 | Generator loss: 2.2663 | Real score: 0.7516 | Fake score: 0.2504
# Epoch [  7/ 25] | Discriminator loss: 0.8768 | Generator loss: 1.8831 | Real score: 0.7073 | Fake score: 0.2964
# Epoch [  8/ 25] | Discriminator loss: 0.9579 | Generator loss: 1.6415 | Real score: 0.6747 | Fake score: 0.3248
# Epoch [  9/ 25] | Discriminator loss: 1.0186 | Generator loss: 1.4846 | Real score: 0.6512 | Fake score: 0.3496
# Epoch [ 10/ 25] | Discriminator loss: 1.0658 | Generator loss: 1.4122 | Real score: 0.6343 | Fake score: 0.3666
# Epoch [ 11/ 25] | Discriminator loss: 1.1054 | Generator loss: 1.2836 | Real score: 0.6187 | Fake score: 0.3821
# Epoch [ 12/ 25] | Discriminator loss: 1.1095 | Generator loss: 1.2403 | Real score: 0.6138 | Fake score: 0.3862
# Epoch [ 13/ 25] | Discriminator loss: 1.1471 | Generator loss: 1.2447 | Real score: 0.6031 | Fake score: 0.3963
# Epoch [ 14/ 25] | Discriminator loss: 1.1793 | Generator loss: 1.1630 | Real score: 0.5932 | Fake score: 0.4072
# Epoch [ 15/ 25] | Discriminator loss: 1.2227 | Generator loss: 1.0874 | Real score: 0.5762 | Fake score: 0.4244
# Epoch [ 16/ 25] | Discriminator loss: 1.2295 | Generator loss: 1.0770 | Real score: 0.5695 | Fake score: 0.4311
# Epoch [ 17/ 25] | Discriminator loss: 1.2608 | Generator loss: 1.0401 | Real score: 0.5601 | Fake score: 0.4406
# Epoch [ 18/ 25] | Discriminator loss: 1.2701 | Generator loss: 1.0079 | Real score: 0.5532 | Fake score: 0.4456
# Epoch [ 19/ 25] | Discriminator loss: 1.2893 | Generator loss: 0.9870 | Real score: 0.5476 | Fake score: 0.4528
# Epoch [ 20/ 25] | Discriminator loss: 1.3008 | Generator loss: 0.9527 | Real score: 0.5425 | Fake score: 0.4582
# Epoch [ 21/ 25] | Discriminator loss: 1.3121 | Generator loss: 0.9273 | Real score: 0.5376 | Fake score: 0.4634
# Epoch [ 22/ 25] | Discriminator loss: 1.3119 | Generator loss: 0.9170 | Real score: 0.5365 | Fake score: 0.4647
# Epoch [ 23/ 25] | Discriminator loss: 1.3300 | Generator loss: 0.8986 | Real score: 0.5300 | Fake score: 0.4695
# Epoch [ 24/ 25] | Discriminator loss: 1.3309 | Generator loss: 0.8703 | Real score: 0.5287 | Fake score: 0.4723
# Epoch [ 25/ 25] | Discriminator loss: 1.3373 | Generator loss: 0.8466 | Real score: 0.5262 | Fake score: 0.4748
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 25] | Discriminator loss: 1.1063 | Generator loss: 0.7075 | Real score: 0.7169 | Fake score: 0.5157
# Epoch [  2/ 25] | Discriminator loss: 0.5339 | Generator loss: 1.3013 | Real score: 0.9546 | Fake score: 0.3677
# Epoch [  3/ 25] | Discriminator loss: 0.2508 | Generator loss: 2.6191 | Real score: 0.9476 | Fake score: 0.1285
# Epoch [  4/ 25] | Discriminator loss: 0.2432 | Generator loss: 3.7157 | Real score: 0.9389 | Fake score: 0.0783
# Epoch [  5/ 25] | Discriminator loss: 0.2220 | Generator loss: 3.9455 | Real score: 0.9412 | Fake score: 0.0653
# Epoch [  6/ 25] | Discriminator loss: 0.1773 | Generator loss: 4.8437 | Real score: 0.9497 | Fake score: 0.0464
# Epoch [  7/ 25] | Discriminator loss: 0.2256 | Generator loss: 4.5591 | Real score: 0.9352 | Fake score: 0.0658
# Epoch [  8/ 25] | Discriminator loss: 0.3783 | Generator loss: 5.0366 | Real score: 0.8796 | Fake score: 0.1107
# Epoch [  9/ 25] | Discriminator loss: 0.2853 | Generator loss: 4.2103 | Real score: 0.8989 | Fake score: 0.0906
# Epoch [ 10/ 25] | Discriminator loss: 0.2343 | Generator loss: 4.5057 | Real score: 0.9249 | Fake score: 0.0784
# Epoch [ 11/ 25] | Discriminator loss: 0.2687 | Generator loss: 4.6611 | Real score: 0.9196 | Fake score: 0.0854
# Epoch [ 12/ 25] | Discriminator loss: 0.3165 | Generator loss: 4.6906 | Real score: 0.9012 | Fake score: 0.0997
# Epoch [ 13/ 25] | Discriminator loss: 0.3569 | Generator loss: 4.9216 | Real score: 0.8976 | Fake score: 0.1111
# Epoch [ 14/ 25] | Discriminator loss: 0.3273 | Generator loss: 4.8401 | Real score: 0.8992 | Fake score: 0.1001
# Epoch [ 15/ 25] | Discriminator loss: 0.3807 | Generator loss: 4.4785 | Real score: 0.8852 | Fake score: 0.1208
# Epoch [ 16/ 25] | Discriminator loss: 0.4207 | Generator loss: 4.0513 | Real score: 0.8806 | Fake score: 0.1316
# Epoch [ 17/ 25] | Discriminator loss: 0.4584 | Generator loss: 4.0685 | Real score: 0.8666 | Fake score: 0.1423
# Epoch [ 18/ 25] | Discriminator loss: 0.4981 | Generator loss: 3.9875 | Real score: 0.8531 | Fake score: 0.1526
# Epoch [ 19/ 25] | Discriminator loss: 0.5534 | Generator loss: 3.5096 | Real score: 0.8247 | Fake score: 0.1709
# Epoch [ 20/ 25] | Discriminator loss: 0.5442 | Generator loss: 3.2505 | Real score: 0.8253 | Fake score: 0.1781
# Epoch [ 21/ 25] | Discriminator loss: 0.6231 | Generator loss: 3.1786 | Real score: 0.8097 | Fake score: 0.2022
# Epoch [ 22/ 25] | Discriminator loss: 0.6400 | Generator loss: 3.1260 | Real score: 0.8014 | Fake score: 0.2046
# Epoch [ 23/ 25] | Discriminator loss: 0.7028 | Generator loss: 2.9788 | Real score: 0.7784 | Fake score: 0.2235
# Epoch [ 24/ 25] | Discriminator loss: 0.6564 | Generator loss: 2.8027 | Real score: 0.7812 | Fake score: 0.2193
# Epoch [ 25/ 25] | Discriminator loss: 0.7048 | Generator loss: 2.6955 | Real score: 0.7776 | Fake score: 0.2333
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 87.47% (Accuracy Loss: 2.44%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.87% (Accuracy Loss: 0.04%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0929
# Reconstruction Error of Anonymized Test Embeddings: 0.0806
# Variance Retention of Anonymized Train Embeddings: 0.9646
# Variance Retention of Anonymized Test Embeddings: 0.7234
# Projection Robustness of Anonymized Train Embeddings: 0.2668
# Projection Robustness of Anonymized Test Embeddings: 2.1459
# FID between Original and Anonymized Train Embeddings: -2.1045e+28
# FID between Original and Anonymized Test Embeddings: -4.1206e+37
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 30 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 30
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 30] | Discriminator loss: 0.4378 | Generator loss: 2.6544 | Real score: 0.9006 | Fake score: 0.2169
# Epoch [  2/ 30] | Discriminator loss: 0.3047 | Generator loss: 4.3080 | Real score: 0.8995 | Fake score: 0.0937
# Epoch [  3/ 30] | Discriminator loss: 0.4232 | Generator loss: 3.9529 | Real score: 0.8615 | Fake score: 0.1367
# Epoch [  4/ 30] | Discriminator loss: 0.5626 | Generator loss: 3.2223 | Real score: 0.8139 | Fake score: 0.1870
# Epoch [  5/ 30] | Discriminator loss: 0.6790 | Generator loss: 2.6556 | Real score: 0.7753 | Fake score: 0.2257
# Epoch [  6/ 30] | Discriminator loss: 0.8113 | Generator loss: 2.2570 | Real score: 0.7344 | Fake score: 0.2701
# Epoch [  7/ 30] | Discriminator loss: 0.9414 | Generator loss: 1.7482 | Real score: 0.6844 | Fake score: 0.3186
# Epoch [  8/ 30] | Discriminator loss: 1.0513 | Generator loss: 1.4735 | Real score: 0.6417 | Fake score: 0.3555
# Epoch [  9/ 30] | Discriminator loss: 1.0928 | Generator loss: 1.3174 | Real score: 0.6254 | Fake score: 0.3756
# Epoch [ 10/ 30] | Discriminator loss: 1.1242 | Generator loss: 1.2584 | Real score: 0.6116 | Fake score: 0.3890
# Epoch [ 11/ 30] | Discriminator loss: 1.1515 | Generator loss: 1.2306 | Real score: 0.6016 | Fake score: 0.3964
# Epoch [ 12/ 30] | Discriminator loss: 1.1777 | Generator loss: 1.1462 | Real score: 0.5917 | Fake score: 0.4091
# Epoch [ 13/ 30] | Discriminator loss: 1.1995 | Generator loss: 1.1453 | Real score: 0.5817 | Fake score: 0.4177
# Epoch [ 14/ 30] | Discriminator loss: 1.2301 | Generator loss: 1.0752 | Real score: 0.5710 | Fake score: 0.4290
# Epoch [ 15/ 30] | Discriminator loss: 1.2632 | Generator loss: 1.0256 | Real score: 0.5586 | Fake score: 0.4421
# Epoch [ 16/ 30] | Discriminator loss: 1.2831 | Generator loss: 0.9883 | Real score: 0.5506 | Fake score: 0.4498
# Epoch [ 17/ 30] | Discriminator loss: 1.2980 | Generator loss: 0.9595 | Real score: 0.5433 | Fake score: 0.4559
# Epoch [ 18/ 30] | Discriminator loss: 1.3121 | Generator loss: 0.9282 | Real score: 0.5375 | Fake score: 0.4634
# Epoch [ 19/ 30] | Discriminator loss: 1.3237 | Generator loss: 0.9129 | Real score: 0.5324 | Fake score: 0.4673
# Epoch [ 20/ 30] | Discriminator loss: 1.3330 | Generator loss: 0.8801 | Real score: 0.5285 | Fake score: 0.4719
# Epoch [ 21/ 30] | Discriminator loss: 1.3391 | Generator loss: 0.8655 | Real score: 0.5262 | Fake score: 0.4747
# Epoch [ 22/ 30] | Discriminator loss: 1.3362 | Generator loss: 0.8615 | Real score: 0.5254 | Fake score: 0.4754
# Epoch [ 23/ 30] | Discriminator loss: 1.3391 | Generator loss: 0.8663 | Real score: 0.5243 | Fake score: 0.4757
# Epoch [ 24/ 30] | Discriminator loss: 1.3459 | Generator loss: 0.8457 | Real score: 0.5217 | Fake score: 0.4796
# Epoch [ 25/ 30] | Discriminator loss: 1.3474 | Generator loss: 0.8434 | Real score: 0.5205 | Fake score: 0.4794
# Epoch [ 26/ 30] | Discriminator loss: 1.3523 | Generator loss: 0.8243 | Real score: 0.5187 | Fake score: 0.4815
# Epoch [ 27/ 30] | Discriminator loss: 1.3564 | Generator loss: 0.8123 | Real score: 0.5167 | Fake score: 0.4834
# Epoch [ 28/ 30] | Discriminator loss: 1.3591 | Generator loss: 0.7953 | Real score: 0.5150 | Fake score: 0.4852
# Epoch [ 29/ 30] | Discriminator loss: 1.3640 | Generator loss: 0.7895 | Real score: 0.5133 | Fake score: 0.4874
# Epoch [ 30/ 30] | Discriminator loss: 1.3637 | Generator loss: 0.7844 | Real score: 0.5131 | Fake score: 0.4884
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 30] | Discriminator loss: 1.1181 | Generator loss: 0.7262 | Real score: 0.7069 | Fake score: 0.5128
# Epoch [  2/ 30] | Discriminator loss: 0.5659 | Generator loss: 1.4077 | Real score: 0.9211 | Fake score: 0.3496
# Epoch [  3/ 30] | Discriminator loss: 0.2317 | Generator loss: 2.7458 | Real score: 0.9462 | Fake score: 0.1172
# Epoch [  4/ 30] | Discriminator loss: 0.1907 | Generator loss: 3.6173 | Real score: 0.9588 | Fake score: 0.0690
# Epoch [  5/ 30] | Discriminator loss: 0.1831 | Generator loss: 4.0635 | Real score: 0.9540 | Fake score: 0.0510
# Epoch [  6/ 30] | Discriminator loss: 0.1880 | Generator loss: 4.5944 | Real score: 0.9532 | Fake score: 0.0533
# Epoch [  7/ 30] | Discriminator loss: 0.1501 | Generator loss: 5.3304 | Real score: 0.9626 | Fake score: 0.0381
# Epoch [  8/ 30] | Discriminator loss: 0.2777 | Generator loss: 5.1806 | Real score: 0.9182 | Fake score: 0.0682
# Epoch [  9/ 30] | Discriminator loss: 0.2516 | Generator loss: 4.5759 | Real score: 0.9259 | Fake score: 0.0713
# Epoch [ 10/ 30] | Discriminator loss: 0.2150 | Generator loss: 4.9791 | Real score: 0.9392 | Fake score: 0.0593
# Epoch [ 11/ 30] | Discriminator loss: 0.2924 | Generator loss: 4.8911 | Real score: 0.9202 | Fake score: 0.0878
# Epoch [ 12/ 30] | Discriminator loss: 0.3295 | Generator loss: 4.2814 | Real score: 0.9051 | Fake score: 0.0850
# Epoch [ 13/ 30] | Discriminator loss: 0.2852 | Generator loss: 4.1114 | Real score: 0.9158 | Fake score: 0.0878
# Epoch [ 14/ 30] | Discriminator loss: 0.3498 | Generator loss: 4.5091 | Real score: 0.9004 | Fake score: 0.1083
# Epoch [ 15/ 30] | Discriminator loss: 0.3468 | Generator loss: 4.2374 | Real score: 0.8919 | Fake score: 0.1087
# Epoch [ 16/ 30] | Discriminator loss: 0.3265 | Generator loss: 4.3187 | Real score: 0.8983 | Fake score: 0.1032
# Epoch [ 17/ 30] | Discriminator loss: 0.4210 | Generator loss: 3.7502 | Real score: 0.8788 | Fake score: 0.1286
# Epoch [ 18/ 30] | Discriminator loss: 0.3973 | Generator loss: 3.6112 | Real score: 0.8783 | Fake score: 0.1251
# Epoch [ 19/ 30] | Discriminator loss: 0.4662 | Generator loss: 3.5155 | Real score: 0.8582 | Fake score: 0.1432
# Epoch [ 20/ 30] | Discriminator loss: 0.4749 | Generator loss: 3.4658 | Real score: 0.8516 | Fake score: 0.1512
# Epoch [ 21/ 30] | Discriminator loss: 0.4926 | Generator loss: 3.3110 | Real score: 0.8481 | Fake score: 0.1611
# Epoch [ 22/ 30] | Discriminator loss: 0.6074 | Generator loss: 3.3833 | Real score: 0.8222 | Fake score: 0.1896
# Epoch [ 23/ 30] | Discriminator loss: 0.5725 | Generator loss: 3.1332 | Real score: 0.8132 | Fake score: 0.1891
# Epoch [ 24/ 30] | Discriminator loss: 0.5383 | Generator loss: 3.1520 | Real score: 0.8265 | Fake score: 0.1752
# Epoch [ 25/ 30] | Discriminator loss: 0.5975 | Generator loss: 3.2432 | Real score: 0.8084 | Fake score: 0.1934
# Epoch [ 26/ 30] | Discriminator loss: 0.6363 | Generator loss: 3.1350 | Real score: 0.7985 | Fake score: 0.2081
# Epoch [ 27/ 30] | Discriminator loss: 0.6236 | Generator loss: 2.9422 | Real score: 0.8001 | Fake score: 0.2013
# Epoch [ 28/ 30] | Discriminator loss: 0.6592 | Generator loss: 2.7666 | Real score: 0.7983 | Fake score: 0.2068
# Epoch [ 29/ 30] | Discriminator loss: 0.7677 | Generator loss: 2.5678 | Real score: 0.7673 | Fake score: 0.2402
# Epoch [ 30/ 30] | Discriminator loss: 0.7430 | Generator loss: 2.3129 | Real score: 0.7534 | Fake score: 0.2490
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 93.54% (Accuracy Loss: -3.63%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.92% (Accuracy Loss: -0.01%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0948
# Reconstruction Error of Anonymized Test Embeddings: 0.0938
# Variance Retention of Anonymized Train Embeddings: 0.9955
# Variance Retention of Anonymized Test Embeddings: 0.9779
# Projection Robustness of Anonymized Train Embeddings: 0.1123
# Projection Robustness of Anonymized Test Embeddings: 1.2771
# FID between Original and Anonymized Train Embeddings: -2.9409e+32
# FID between Original and Anonymized Test Embeddings: 2.2459e+40
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 40 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 40
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 40] | Discriminator loss: 0.4025 | Generator loss: 2.6273 | Real score: 0.9127 | Fake score: 0.2054
# Epoch [  2/ 40] | Discriminator loss: 0.2746 | Generator loss: 4.5443 | Real score: 0.9129 | Fake score: 0.0769
# Epoch [  3/ 40] | Discriminator loss: 0.4178 | Generator loss: 3.8340 | Real score: 0.8650 | Fake score: 0.1318
# Epoch [  4/ 40] | Discriminator loss: 0.5015 | Generator loss: 3.5543 | Real score: 0.8400 | Fake score: 0.1624
# Epoch [  5/ 40] | Discriminator loss: 0.6258 | Generator loss: 2.7273 | Real score: 0.7941 | Fake score: 0.2070
# Epoch [  6/ 40] | Discriminator loss: 0.7622 | Generator loss: 2.2663 | Real score: 0.7516 | Fake score: 0.2504
# Epoch [  7/ 40] | Discriminator loss: 0.8768 | Generator loss: 1.8831 | Real score: 0.7073 | Fake score: 0.2964
# Epoch [  8/ 40] | Discriminator loss: 0.9579 | Generator loss: 1.6415 | Real score: 0.6747 | Fake score: 0.3248
# Epoch [  9/ 40] | Discriminator loss: 1.0186 | Generator loss: 1.4846 | Real score: 0.6512 | Fake score: 0.3496
# Epoch [ 10/ 40] | Discriminator loss: 1.0658 | Generator loss: 1.4122 | Real score: 0.6343 | Fake score: 0.3666
# Epoch [ 11/ 40] | Discriminator loss: 1.1054 | Generator loss: 1.2836 | Real score: 0.6187 | Fake score: 0.3821
# Epoch [ 12/ 40] | Discriminator loss: 1.1095 | Generator loss: 1.2403 | Real score: 0.6138 | Fake score: 0.3862
# Epoch [ 13/ 40] | Discriminator loss: 1.1471 | Generator loss: 1.2447 | Real score: 0.6031 | Fake score: 0.3963
# Epoch [ 14/ 40] | Discriminator loss: 1.1793 | Generator loss: 1.1630 | Real score: 0.5932 | Fake score: 0.4072
# Epoch [ 15/ 40] | Discriminator loss: 1.2227 | Generator loss: 1.0874 | Real score: 0.5762 | Fake score: 0.4244
# Epoch [ 16/ 40] | Discriminator loss: 1.2295 | Generator loss: 1.0770 | Real score: 0.5695 | Fake score: 0.4311
# Epoch [ 17/ 40] | Discriminator loss: 1.2608 | Generator loss: 1.0401 | Real score: 0.5601 | Fake score: 0.4406
# Epoch [ 18/ 40] | Discriminator loss: 1.2701 | Generator loss: 1.0079 | Real score: 0.5532 | Fake score: 0.4456
# Epoch [ 19/ 40] | Discriminator loss: 1.2893 | Generator loss: 0.9870 | Real score: 0.5476 | Fake score: 0.4528
# Epoch [ 20/ 40] | Discriminator loss: 1.3008 | Generator loss: 0.9527 | Real score: 0.5425 | Fake score: 0.4582
# Epoch [ 21/ 40] | Discriminator loss: 1.3121 | Generator loss: 0.9273 | Real score: 0.5376 | Fake score: 0.4634
# Epoch [ 22/ 40] | Discriminator loss: 1.3119 | Generator loss: 0.9170 | Real score: 0.5365 | Fake score: 0.4647
# Epoch [ 23/ 40] | Discriminator loss: 1.3300 | Generator loss: 0.8986 | Real score: 0.5300 | Fake score: 0.4695
# Epoch [ 24/ 40] | Discriminator loss: 1.3309 | Generator loss: 0.8703 | Real score: 0.5287 | Fake score: 0.4723
# Epoch [ 25/ 40] | Discriminator loss: 1.3373 | Generator loss: 0.8466 | Real score: 0.5262 | Fake score: 0.4748
# Epoch [ 26/ 40] | Discriminator loss: 1.3408 | Generator loss: 0.8510 | Real score: 0.5238 | Fake score: 0.4767
# Epoch [ 27/ 40] | Discriminator loss: 1.3468 | Generator loss: 0.8426 | Real score: 0.5214 | Fake score: 0.4796
# Epoch [ 28/ 40] | Discriminator loss: 1.3457 | Generator loss: 0.8456 | Real score: 0.5207 | Fake score: 0.4783
# Epoch [ 29/ 40] | Discriminator loss: 1.3517 | Generator loss: 0.8164 | Real score: 0.5182 | Fake score: 0.4821
# Epoch [ 30/ 40] | Discriminator loss: 1.3515 | Generator loss: 0.8149 | Real score: 0.5180 | Fake score: 0.4821
# Epoch [ 31/ 40] | Discriminator loss: 1.3551 | Generator loss: 0.8123 | Real score: 0.5169 | Fake score: 0.4837
# Epoch [ 32/ 40] | Discriminator loss: 1.3587 | Generator loss: 0.8004 | Real score: 0.5151 | Fake score: 0.4857
# Epoch [ 33/ 40] | Discriminator loss: 1.3620 | Generator loss: 0.7904 | Real score: 0.5135 | Fake score: 0.4869
# Epoch [ 34/ 40] | Discriminator loss: 1.3644 | Generator loss: 0.7808 | Real score: 0.5127 | Fake score: 0.4883
# Epoch [ 35/ 40] | Discriminator loss: 1.3652 | Generator loss: 0.7785 | Real score: 0.5122 | Fake score: 0.4884
# Epoch [ 36/ 40] | Discriminator loss: 1.3675 | Generator loss: 0.7744 | Real score: 0.5113 | Fake score: 0.4903
# Epoch [ 37/ 40] | Discriminator loss: 1.3703 | Generator loss: 0.7682 | Real score: 0.5096 | Fake score: 0.4912
# Epoch [ 38/ 40] | Discriminator loss: 1.3723 | Generator loss: 0.7644 | Real score: 0.5087 | Fake score: 0.4919
# Epoch [ 39/ 40] | Discriminator loss: 1.3737 | Generator loss: 0.7566 | Real score: 0.5080 | Fake score: 0.4929
# Epoch [ 40/ 40] | Discriminator loss: 1.3749 | Generator loss: 0.7451 | Real score: 0.5068 | Fake score: 0.4936
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 40] | Discriminator loss: 1.0891 | Generator loss: 0.7240 | Real score: 0.7211 | Fake score: 0.5092
# Epoch [  2/ 40] | Discriminator loss: 0.4863 | Generator loss: 1.1767 | Real score: 0.9824 | Fake score: 0.3633
# Epoch [  3/ 40] | Discriminator loss: 0.2282 | Generator loss: 2.6668 | Real score: 0.9671 | Fake score: 0.1322
# Epoch [  4/ 40] | Discriminator loss: 0.1466 | Generator loss: 3.8530 | Real score: 0.9701 | Fake score: 0.0528
# Epoch [  5/ 40] | Discriminator loss: 0.1687 | Generator loss: 4.4814 | Real score: 0.9569 | Fake score: 0.0438
# Epoch [  6/ 40] | Discriminator loss: 0.1789 | Generator loss: 4.4159 | Real score: 0.9532 | Fake score: 0.0472
# Epoch [  7/ 40] | Discriminator loss: 0.1929 | Generator loss: 4.9792 | Real score: 0.9448 | Fake score: 0.0515
# Epoch [  8/ 40] | Discriminator loss: 0.1878 | Generator loss: 4.7107 | Real score: 0.9399 | Fake score: 0.0527
# Epoch [  9/ 40] | Discriminator loss: 0.3517 | Generator loss: 4.5400 | Real score: 0.8967 | Fake score: 0.1053
# Epoch [ 10/ 40] | Discriminator loss: 0.2807 | Generator loss: 4.0534 | Real score: 0.8999 | Fake score: 0.0945
# Epoch [ 11/ 40] | Discriminator loss: 0.2459 | Generator loss: 4.7732 | Real score: 0.9256 | Fake score: 0.0745
# Epoch [ 12/ 40] | Discriminator loss: 0.2630 | Generator loss: 4.9097 | Real score: 0.9268 | Fake score: 0.0800
# Epoch [ 13/ 40] | Discriminator loss: 0.2961 | Generator loss: 4.8669 | Real score: 0.9170 | Fake score: 0.0830
# Epoch [ 14/ 40] | Discriminator loss: 0.3860 | Generator loss: 4.5052 | Real score: 0.8918 | Fake score: 0.1168
# Epoch [ 15/ 40] | Discriminator loss: 0.3577 | Generator loss: 4.1945 | Real score: 0.8864 | Fake score: 0.1108
# Epoch [ 16/ 40] | Discriminator loss: 0.3611 | Generator loss: 3.8504 | Real score: 0.8923 | Fake score: 0.1191
# Epoch [ 17/ 40] | Discriminator loss: 0.4570 | Generator loss: 4.0055 | Real score: 0.8523 | Fake score: 0.1476
# Epoch [ 18/ 40] | Discriminator loss: 0.4010 | Generator loss: 3.7712 | Real score: 0.8672 | Fake score: 0.1375
# Epoch [ 19/ 40] | Discriminator loss: 0.4715 | Generator loss: 3.7037 | Real score: 0.8546 | Fake score: 0.1534
# Epoch [ 20/ 40] | Discriminator loss: 0.6015 | Generator loss: 3.5568 | Real score: 0.8163 | Fake score: 0.1960
# Epoch [ 21/ 40] | Discriminator loss: 0.6415 | Generator loss: 3.7743 | Real score: 0.8020 | Fake score: 0.2008
# Epoch [ 22/ 40] | Discriminator loss: 0.5747 | Generator loss: 3.4120 | Real score: 0.8120 | Fake score: 0.1851
# Epoch [ 23/ 40] | Discriminator loss: 0.6080 | Generator loss: 2.8914 | Real score: 0.8036 | Fake score: 0.2085
# Epoch [ 24/ 40] | Discriminator loss: 0.6252 | Generator loss: 2.9409 | Real score: 0.7954 | Fake score: 0.2084
# Epoch [ 25/ 40] | Discriminator loss: 0.6597 | Generator loss: 3.1054 | Real score: 0.7844 | Fake score: 0.2167
# Epoch [ 26/ 40] | Discriminator loss: 0.7331 | Generator loss: 3.0046 | Real score: 0.7686 | Fake score: 0.2364
# Epoch [ 27/ 40] | Discriminator loss: 0.7184 | Generator loss: 2.7501 | Real score: 0.7584 | Fake score: 0.2412
# Epoch [ 28/ 40] | Discriminator loss: 0.6439 | Generator loss: 2.7316 | Real score: 0.7816 | Fake score: 0.2159
# Epoch [ 29/ 40] | Discriminator loss: 0.6934 | Generator loss: 2.6389 | Real score: 0.7705 | Fake score: 0.2288
# Epoch [ 30/ 40] | Discriminator loss: 0.7569 | Generator loss: 2.4465 | Real score: 0.7584 | Fake score: 0.2437
# Epoch [ 31/ 40] | Discriminator loss: 0.8664 | Generator loss: 2.3760 | Real score: 0.7280 | Fake score: 0.2765
# Epoch [ 32/ 40] | Discriminator loss: 0.8603 | Generator loss: 2.2365 | Real score: 0.7189 | Fake score: 0.2912
# Epoch [ 33/ 40] | Discriminator loss: 0.8458 | Generator loss: 2.2201 | Real score: 0.7177 | Fake score: 0.2886
# Epoch [ 34/ 40] | Discriminator loss: 0.8517 | Generator loss: 2.1381 | Real score: 0.7151 | Fake score: 0.2910
# Epoch [ 35/ 40] | Discriminator loss: 0.8956 | Generator loss: 2.0372 | Real score: 0.7036 | Fake score: 0.3016
# Epoch [ 36/ 40] | Discriminator loss: 0.9191 | Generator loss: 1.9279 | Real score: 0.6954 | Fake score: 0.3073
# Epoch [ 37/ 40] | Discriminator loss: 1.0039 | Generator loss: 1.8739 | Real score: 0.6701 | Fake score: 0.3385
# Epoch [ 38/ 40] | Discriminator loss: 0.9862 | Generator loss: 1.8797 | Real score: 0.6700 | Fake score: 0.3332
# Epoch [ 39/ 40] | Discriminator loss: 0.9711 | Generator loss: 1.8129 | Real score: 0.6724 | Fake score: 0.3315
# Epoch [ 40/ 40] | Discriminator loss: 0.9950 | Generator loss: 1.6560 | Real score: 0.6626 | Fake score: 0.3413
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 90.32% (Accuracy Loss: -0.41%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.66% (Accuracy Loss: 0.25%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0939
# Reconstruction Error of Anonymized Test Embeddings: 0.0806
# Variance Retention of Anonymized Train Embeddings: 0.9829
# Variance Retention of Anonymized Test Embeddings: 0.7761
# Projection Robustness of Anonymized Train Embeddings: 0.1208
# Projection Robustness of Anonymized Test Embeddings: 1.5670
# FID between Original and Anonymized Train Embeddings: 4.8329e+30
# FID between Original and Anonymized Test Embeddings: -1.4538e+35
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# #### 50 epochs

# %%
# Hyperparameters
d_conv_dim = 32
g_conv_dim = 32
latent_dim = 100
embedding_size = 768
lr = 0.0002
n_epochs = 50
batch_size = 64

# %%
# Train GAN on CIFAR10 train embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_train_embeddings_database = np.load(f'embeddings/{output_folder}/train_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_train_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/train_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 50] | Discriminator loss: 0.4110 | Generator loss: 2.4845 | Real score: 0.9199 | Fake score: 0.2220
# Epoch [  2/ 50] | Discriminator loss: 0.3052 | Generator loss: 4.3301 | Real score: 0.8986 | Fake score: 0.0950
# Epoch [  3/ 50] | Discriminator loss: 0.4399 | Generator loss: 3.7321 | Real score: 0.8587 | Fake score: 0.1409
# Epoch [  4/ 50] | Discriminator loss: 0.5278 | Generator loss: 3.4539 | Real score: 0.8270 | Fake score: 0.1697
# Epoch [  5/ 50] | Discriminator loss: 0.6152 | Generator loss: 2.8792 | Real score: 0.8005 | Fake score: 0.2038
# Epoch [  6/ 50] | Discriminator loss: 0.7954 | Generator loss: 2.3003 | Real score: 0.7461 | Fake score: 0.2593
# Epoch [  7/ 50] | Discriminator loss: 0.9153 | Generator loss: 1.8361 | Real score: 0.6926 | Fake score: 0.3083
# Epoch [  8/ 50] | Discriminator loss: 0.9736 | Generator loss: 1.6883 | Real score: 0.6675 | Fake score: 0.3320
# Epoch [  9/ 50] | Discriminator loss: 1.0572 | Generator loss: 1.4574 | Real score: 0.6382 | Fake score: 0.3605
# Epoch [ 10/ 50] | Discriminator loss: 1.0795 | Generator loss: 1.3612 | Real score: 0.6274 | Fake score: 0.3719
# Epoch [ 11/ 50] | Discriminator loss: 1.1114 | Generator loss: 1.2536 | Real score: 0.6174 | Fake score: 0.3811
# Epoch [ 12/ 50] | Discriminator loss: 1.1254 | Generator loss: 1.2172 | Real score: 0.6096 | Fake score: 0.3894
# Epoch [ 13/ 50] | Discriminator loss: 1.1375 | Generator loss: 1.1869 | Real score: 0.6042 | Fake score: 0.3944
# Epoch [ 14/ 50] | Discriminator loss: 1.1588 | Generator loss: 1.1160 | Real score: 0.5955 | Fake score: 0.4016
# Epoch [ 15/ 50] | Discriminator loss: 1.1662 | Generator loss: 1.1159 | Real score: 0.5939 | Fake score: 0.4065
# Epoch [ 16/ 50] | Discriminator loss: 1.1859 | Generator loss: 1.0787 | Real score: 0.5855 | Fake score: 0.4120
# Epoch [ 17/ 50] | Discriminator loss: 1.2275 | Generator loss: 1.0455 | Real score: 0.5723 | Fake score: 0.4285
# Epoch [ 18/ 50] | Discriminator loss: 1.2513 | Generator loss: 1.0003 | Real score: 0.5614 | Fake score: 0.4376
# Epoch [ 19/ 50] | Discriminator loss: 1.2776 | Generator loss: 0.9535 | Real score: 0.5501 | Fake score: 0.4482
# Epoch [ 20/ 50] | Discriminator loss: 1.2851 | Generator loss: 0.9571 | Real score: 0.5464 | Fake score: 0.4517
# Epoch [ 21/ 50] | Discriminator loss: 1.2952 | Generator loss: 0.9136 | Real score: 0.5437 | Fake score: 0.4567
# Epoch [ 22/ 50] | Discriminator loss: 1.3096 | Generator loss: 0.9167 | Real score: 0.5370 | Fake score: 0.4612
# Epoch [ 23/ 50] | Discriminator loss: 1.3189 | Generator loss: 0.8752 | Real score: 0.5333 | Fake score: 0.4678
# Epoch [ 24/ 50] | Discriminator loss: 1.3263 | Generator loss: 0.8727 | Real score: 0.5288 | Fake score: 0.4699
# Epoch [ 25/ 50] | Discriminator loss: 1.3320 | Generator loss: 0.8693 | Real score: 0.5270 | Fake score: 0.4722
# Epoch [ 26/ 50] | Discriminator loss: 1.3296 | Generator loss: 0.8537 | Real score: 0.5269 | Fake score: 0.4712
# Epoch [ 27/ 50] | Discriminator loss: 1.3385 | Generator loss: 0.8337 | Real score: 0.5247 | Fake score: 0.4761
# Epoch [ 28/ 50] | Discriminator loss: 1.3402 | Generator loss: 0.8338 | Real score: 0.5239 | Fake score: 0.4771
# Epoch [ 29/ 50] | Discriminator loss: 1.3411 | Generator loss: 0.8228 | Real score: 0.5245 | Fake score: 0.4786
# Epoch [ 30/ 50] | Discriminator loss: 1.3411 | Generator loss: 0.8359 | Real score: 0.5235 | Fake score: 0.4771
# Epoch [ 31/ 50] | Discriminator loss: 1.3469 | Generator loss: 0.8183 | Real score: 0.5205 | Fake score: 0.4791
# Epoch [ 32/ 50] | Discriminator loss: 1.3503 | Generator loss: 0.8049 | Real score: 0.5196 | Fake score: 0.4820
# Epoch [ 33/ 50] | Discriminator loss: 1.3522 | Generator loss: 0.7927 | Real score: 0.5192 | Fake score: 0.4836
# Epoch [ 34/ 50] | Discriminator loss: 1.3548 | Generator loss: 0.7913 | Real score: 0.5172 | Fake score: 0.4845
# Epoch [ 35/ 50] | Discriminator loss: 1.3598 | Generator loss: 0.7876 | Real score: 0.5153 | Fake score: 0.4862
# Epoch [ 36/ 50] | Discriminator loss: 1.3600 | Generator loss: 0.7856 | Real score: 0.5137 | Fake score: 0.4855
# Epoch [ 37/ 50] | Discriminator loss: 1.3641 | Generator loss: 0.7720 | Real score: 0.5139 | Fake score: 0.4892
# Epoch [ 38/ 50] | Discriminator loss: 1.3663 | Generator loss: 0.7675 | Real score: 0.5128 | Fake score: 0.4904
# Epoch [ 39/ 50] | Discriminator loss: 1.3702 | Generator loss: 0.7636 | Real score: 0.5097 | Fake score: 0.4905
# Epoch [ 40/ 50] | Discriminator loss: 1.3717 | Generator loss: 0.7582 | Real score: 0.5083 | Fake score: 0.4910
# Epoch [ 41/ 50] | Discriminator loss: 1.3717 | Generator loss: 0.7569 | Real score: 0.5094 | Fake score: 0.4924
# Epoch [ 42/ 50] | Discriminator loss: 1.3720 | Generator loss: 0.7523 | Real score: 0.5084 | Fake score: 0.4921
# Epoch [ 43/ 50] | Discriminator loss: 1.3746 | Generator loss: 0.7479 | Real score: 0.5073 | Fake score: 0.4931
# Epoch [ 44/ 50] | Discriminator loss: 1.3757 | Generator loss: 0.7451 | Real score: 0.5076 | Fake score: 0.4947
# Epoch [ 45/ 50] | Discriminator loss: 1.3781 | Generator loss: 0.7422 | Real score: 0.5056 | Fake score: 0.4944
# Epoch [ 46/ 50] | Discriminator loss: 1.3773 | Generator loss: 0.7376 | Real score: 0.5058 | Fake score: 0.4945
# Epoch [ 47/ 50] | Discriminator loss: 1.3789 | Generator loss: 0.7362 | Real score: 0.5055 | Fake score: 0.4955
# Epoch [ 48/ 50] | Discriminator loss: 1.3796 | Generator loss: 0.7334 | Real score: 0.5061 | Fake score: 0.4969
# Epoch [ 49/ 50] | Discriminator loss: 1.3784 | Generator loss: 0.7346 | Real score: 0.5052 | Fake score: 0.4954
# Epoch [ 50/ 50] | Discriminator loss: 1.3794 | Generator loss: 0.7344 | Real score: 0.5046 | Fake score: 0.4956
# Saving checkpoint outputs/cifar10/train_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# Train GAN on CIFAR10 test embeddings
from anonymization.anonymization_GAN.GAN_trainer import GANTrainer

output_folder = "cifar10"
model_name = "resnet18_custom"
optim_code = "_13hj"
cp_datetime = "20240130_143435"

trainer = GANTrainer(d_conv_dim, g_conv_dim, latent_dim, embedding_size, lr, device)
real_test_embeddings_database = np.load(f'embeddings/{output_folder}/test_{model_name}{optim_code}_{cp_datetime}.npz')["embeddings"]
# call training function
g_losses, d_losses, real_scores, fake_scores = trainer.fit(real_test_embeddings_database, batch_size, n_epochs, latent_dim)

# Save the trained model
trainer.save_checkpoint(g_losses, d_losses, real_scores, fake_scores, f'outputs/{output_folder}/test_gan_{model_name}{optim_code}_{cp_datetime}.pth')
print('Model Trained and Saved')
# Out:
# Epoch [  1/ 50] | Discriminator loss: 1.0674 | Generator loss: 0.7576 | Real score: 0.7216 | Fake score: 0.4980
# Epoch [  2/ 50] | Discriminator loss: 0.3986 | Generator loss: 1.7781 | Real score: 0.9589 | Fake score: 0.2757
# Epoch [  3/ 50] | Discriminator loss: 0.2145 | Generator loss: 3.1123 | Real score: 0.9533 | Fake score: 0.0951
# Epoch [  4/ 50] | Discriminator loss: 0.1923 | Generator loss: 3.6472 | Real score: 0.9510 | Fake score: 0.0635
# Epoch [  5/ 50] | Discriminator loss: 0.1703 | Generator loss: 5.0242 | Real score: 0.9565 | Fake score: 0.0428
# Epoch [  6/ 50] | Discriminator loss: 0.1858 | Generator loss: 4.3901 | Real score: 0.9502 | Fake score: 0.0510
# Epoch [  7/ 50] | Discriminator loss: 0.2201 | Generator loss: 5.1832 | Real score: 0.9394 | Fake score: 0.0581
# Epoch [  8/ 50] | Discriminator loss: 0.3225 | Generator loss: 4.3595 | Real score: 0.9103 | Fake score: 0.0824
# Epoch [  9/ 50] | Discriminator loss: 0.2831 | Generator loss: 4.2187 | Real score: 0.9194 | Fake score: 0.0844
# Epoch [ 10/ 50] | Discriminator loss: 0.2628 | Generator loss: 4.4799 | Real score: 0.9297 | Fake score: 0.0771
# Epoch [ 11/ 50] | Discriminator loss: 0.2634 | Generator loss: 4.3418 | Real score: 0.9239 | Fake score: 0.0820
# Epoch [ 12/ 50] | Discriminator loss: 0.3700 | Generator loss: 4.0106 | Real score: 0.8900 | Fake score: 0.1085
# Epoch [ 13/ 50] | Discriminator loss: 0.2846 | Generator loss: 4.2040 | Real score: 0.9148 | Fake score: 0.0860
# Epoch [ 14/ 50] | Discriminator loss: 0.3476 | Generator loss: 4.1499 | Real score: 0.9060 | Fake score: 0.1028
# Epoch [ 15/ 50] | Discriminator loss: 0.3514 | Generator loss: 3.7951 | Real score: 0.8988 | Fake score: 0.1073
# Epoch [ 16/ 50] | Discriminator loss: 0.3917 | Generator loss: 3.8662 | Real score: 0.8907 | Fake score: 0.1180
# Epoch [ 17/ 50] | Discriminator loss: 0.3816 | Generator loss: 4.0409 | Real score: 0.8852 | Fake score: 0.1128
# Epoch [ 18/ 50] | Discriminator loss: 0.4316 | Generator loss: 3.7482 | Real score: 0.8752 | Fake score: 0.1308
# Epoch [ 19/ 50] | Discriminator loss: 0.3894 | Generator loss: 3.4653 | Real score: 0.8799 | Fake score: 0.1261
# Epoch [ 20/ 50] | Discriminator loss: 0.4164 | Generator loss: 3.4383 | Real score: 0.8774 | Fake score: 0.1358
# Epoch [ 21/ 50] | Discriminator loss: 0.4974 | Generator loss: 3.6903 | Real score: 0.8546 | Fake score: 0.1541
# Epoch [ 22/ 50] | Discriminator loss: 0.4398 | Generator loss: 3.8715 | Real score: 0.8701 | Fake score: 0.1384
# Epoch [ 23/ 50] | Discriminator loss: 0.4886 | Generator loss: 3.5905 | Real score: 0.8533 | Fake score: 0.1488
# Epoch [ 24/ 50] | Discriminator loss: 0.4719 | Generator loss: 3.4599 | Real score: 0.8550 | Fake score: 0.1480
# Epoch [ 25/ 50] | Discriminator loss: 0.5124 | Generator loss: 3.1895 | Real score: 0.8422 | Fake score: 0.1612
# Epoch [ 26/ 50] | Discriminator loss: 0.5520 | Generator loss: 3.2309 | Real score: 0.8299 | Fake score: 0.1759
# Epoch [ 27/ 50] | Discriminator loss: 0.5666 | Generator loss: 3.2289 | Real score: 0.8261 | Fake score: 0.1840
# Epoch [ 28/ 50] | Discriminator loss: 0.6367 | Generator loss: 2.9321 | Real score: 0.7991 | Fake score: 0.2069
# Epoch [ 29/ 50] | Discriminator loss: 0.5614 | Generator loss: 3.0278 | Real score: 0.8146 | Fake score: 0.1824
# Epoch [ 30/ 50] | Discriminator loss: 0.6329 | Generator loss: 3.1411 | Real score: 0.8009 | Fake score: 0.1997
# Epoch [ 31/ 50] | Discriminator loss: 0.5949 | Generator loss: 2.9560 | Real score: 0.8033 | Fake score: 0.1951
# Epoch [ 32/ 50] | Discriminator loss: 0.6039 | Generator loss: 2.8172 | Real score: 0.7992 | Fake score: 0.2029
# Epoch [ 33/ 50] | Discriminator loss: 0.6589 | Generator loss: 2.8674 | Real score: 0.7902 | Fake score: 0.2113
# Epoch [ 34/ 50] | Discriminator loss: 0.6461 | Generator loss: 3.1640 | Real score: 0.8042 | Fake score: 0.2034
# Epoch [ 35/ 50] | Discriminator loss: 0.7301 | Generator loss: 2.8500 | Real score: 0.7813 | Fake score: 0.2294
# Epoch [ 36/ 50] | Discriminator loss: 0.7170 | Generator loss: 2.5975 | Real score: 0.7700 | Fake score: 0.2344
# Epoch [ 37/ 50] | Discriminator loss: 0.7797 | Generator loss: 2.4894 | Real score: 0.7536 | Fake score: 0.2554
# Epoch [ 38/ 50] | Discriminator loss: 0.7052 | Generator loss: 2.3486 | Real score: 0.7665 | Fake score: 0.2357
# Epoch [ 39/ 50] | Discriminator loss: 0.7605 | Generator loss: 2.2714 | Real score: 0.7545 | Fake score: 0.2548
# Epoch [ 40/ 50] | Discriminator loss: 0.9341 | Generator loss: 2.3531 | Real score: 0.7146 | Fake score: 0.2989
# Epoch [ 41/ 50] | Discriminator loss: 0.8478 | Generator loss: 2.1683 | Real score: 0.7210 | Fake score: 0.2866
# Epoch [ 42/ 50] | Discriminator loss: 0.8728 | Generator loss: 1.9286 | Real score: 0.7099 | Fake score: 0.2943
# Epoch [ 43/ 50] | Discriminator loss: 0.9304 | Generator loss: 1.8061 | Real score: 0.6909 | Fake score: 0.3154
# Epoch [ 44/ 50] | Discriminator loss: 0.9198 | Generator loss: 1.9167 | Real score: 0.6938 | Fake score: 0.3112
# Epoch [ 45/ 50] | Discriminator loss: 0.9506 | Generator loss: 1.8245 | Real score: 0.6864 | Fake score: 0.3222
# Epoch [ 46/ 50] | Discriminator loss: 0.9833 | Generator loss: 2.0148 | Real score: 0.6803 | Fake score: 0.3258
# Epoch [ 47/ 50] | Discriminator loss: 0.9060 | Generator loss: 1.8602 | Real score: 0.6944 | Fake score: 0.3113
# Epoch [ 48/ 50] | Discriminator loss: 0.9930 | Generator loss: 1.7197 | Real score: 0.6698 | Fake score: 0.3327
# Epoch [ 49/ 50] | Discriminator loss: 0.9651 | Generator loss: 1.6633 | Real score: 0.6754 | Fake score: 0.3284
# Epoch [ 50/ 50] | Discriminator loss: 0.9787 | Generator loss: 1.5869 | Real score: 0.6697 | Fake score: 0.3323
# Saving checkpoint outputs/cifar10/test_gan_resnet18_custom_13hj_20240130_143435.pth
# Model Trained and Saved

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --n_neighbors 5 --anonym_method 'gan' --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 89.91%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.64% (Accuracy Loss: 0.27%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 89.51% (Accuracy Loss: 0.40%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0951
# Reconstruction Error of Anonymized Test Embeddings: 0.0807
# Variance Retention of Anonymized Train Embeddings: 1.0020
# Variance Retention of Anonymized Test Embeddings: 0.7527
# Projection Robustness of Anonymized Train Embeddings: 0.1111
# Projection Robustness of Anonymized Test Embeddings: 1.5648
# FID between Original and Anonymized Train Embeddings: -1.8569e+27
# FID between Original and Anonymized Test Embeddings: 2.0769e+34
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %% [markdown]
# # Anonymize DINOv2 embeddings

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240225_003600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'laplace' --noise_scale 0.1 --visualize_embeds
# Out:
# Random seed 42 has been set.
# Device: cpu
#
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier (trained on Original Train Embeddings) Accuracy on Original Test Embeddings: 98.70%
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Anonymized Test Embeddings: 98.66% (Accuracy Loss: 0.04%)
# KNN Classifier (trained on Anonymized Train Embeddings) Accuracy on Original Test Embeddings: 98.69% (Accuracy Loss: 0.01%)
# Reconstruction Error of Anonymized Train Embeddings: 0.0200
# Reconstruction Error of Anonymized Test Embeddings: 0.0200
# Variance Retention of Anonymized Train Embeddings: 1.0068
# Variance Retention of Anonymized Test Embeddings: 1.0068
# Projection Robustness of Anonymized Train Embeddings: 0.2478
# Projection Robustness of Anonymized Test Embeddings: 0.2361
# No Overlap between Original and Anonymized Train Embeddings.
# No Overlap between Original and Anonymized Test Embeddings.
# Figure(2000x1000)
# Visualization of Embeddings Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'laplace' --tuning --noise_scale_tuning 0.1 0.5 1 1.5 2 2.5 3
# Out:
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Original Test Set: 98.70%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.1): 98.66%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=0.5): 98.79%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.0): 98.46%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=1.5): 97.97%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.0): 96.06%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=2.5): 90.67%
# ANONYMIZATION OF EMBEDDINGS FINISHED.
# KNN Classifier Accuracy on Anonymized Test Set (noise_scale=3.0): 81.32%
# Figure(1200x600)
# Plot of Anonymization Accuracy vs Reconstruction Error Saved.

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 1000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds

# %%
# !python knn/knn_classification_anonymized.py --num_classes 10 --cp_datetime '20240126_074600' --model_name 'DINOv2' --n_neighbors 5 --anonym_method 'kmeans' --n_clusters 5000 --assign_labels 'majority' --noise_scale 0.25 --visualize_embeds
