# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/xAI-project-computer-vision

import sys
sys.path.insert(0,'/content/drive/My Drive/Github/xAI-project-computer-vision')

# %pwd
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision
# '/content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision'

# %%
# !pip install torchinfo

# %%
import numpy as np
import random
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import datasets

print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.1.0+cu121
# torchvision version: 0.16.0+cu121

# %%
import models
from utils import print_model_summary, get_available_device, move_to_device, seed_all

device = get_available_device()
print("Device:", device)

seed_all(42)
# Out:
# Device: cuda
#
# Device: cuda
# Random seed 42 has been set.

# %% [markdown]
# # Use simple custom CNNs as feature extractor

# %% [markdown]
# ## Simple custom CNN v1

# %%
# !python knn_classification.py --num_classes 10 --cp_datetime '20240130_115002' --optim_code '_1359' --model_name 'simple_convnet' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds --visualize_knn
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# SimpleConvNet (SimpleConvNet)            [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 16, 32, 32]     448                  True
# ├─MaxPool2d (pool)                       [64, 16, 32, 32]     [64, 16, 16, 16]     --                   --
# ├─Conv2d (conv2)                         [64, 16, 16, 16]     [64, 32, 16, 16]     4,640                True
# ├─MaxPool2d (pool)                       [64, 32, 16, 16]     [64, 32, 8, 8]       --                   --
# ...

# %%
data = np.load('embeddings/cifar10/train_simple_convnet_1359_20240130_115002.npz')
embeddings = data["embeddings"]
embeddings.shape
# Out:
# (50000, 768)

# %% [markdown]
# ## Simple custom CNN v2

# %%
# !python knn_classification.py --num_classes 10 --cp_datetime '20240130_131956' --optim_code '_1359' --model_name 'simple_convnet_v2' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# SimpleConvNetV2 (SimpleConvNetV2)        [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 48, 32, 32]     1,344                True
# ├─Conv2d (conv2)                         [64, 48, 32, 32]     [64, 96, 32, 32]     41,568               True
# ├─MaxPool2d (pool)                       [64, 96, 32, 32]     [64, 96, 16, 16]     --                   --
# ├─Dropout (dropout)                      [64, 96, 16, 16]     [64, 96, 16, 16]     --                   --
# ...

# %% [markdown]
# # Use deeper custom CNNs (based on ResNet) as feature extractor

# %% [markdown]
# ## Simplified custom ResNet

# %%
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240130_120150' --optim_code '_1359' --model_name 'resnet_custom_simplified' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResnetCustomSimplified (ResnetCustomSimplified)    [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Sequential (conv_layer_1)                        [64, 3, 32, 32]      [64, 64, 32, 32]     --                   True
# │    └─Conv2d (0)                                  [64, 3, 32, 32]      [64, 64, 32, 32]     1,792                True
# │    └─BatchNorm2d (1)                             [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# │    └─ReLU (2)                                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   --
# ...

# %%
# TOP MODEL
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240203_002421' --optim_code '_135i' --model_name 'resnet_custom_simplified' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResnetCustomSimplified (ResnetCustomSimplified)    [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Sequential (conv_layer_1)                        [64, 3, 32, 32]      [64, 64, 32, 32]     --                   True
# │    └─Conv2d (0)                                  [64, 3, 32, 32]      [64, 64, 32, 32]     1,792                True
# │    └─BatchNorm2d (1)                             [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# │    └─ReLU (2)                                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   --
# ...

# %%
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240130_140341' --optim_code '_13hi' --model_name 'resnet_custom_simplified' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResnetCustomSimplified (ResnetCustomSimplified)    [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Sequential (conv_layer_1)                        [64, 3, 32, 32]      [64, 64, 32, 32]     --                   True
# │    └─Conv2d (0)                                  [64, 3, 32, 32]      [64, 64, 32, 32]     1,792                True
# │    └─BatchNorm2d (1)                             [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# │    └─ReLU (2)                                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   --
# ...

# %% [markdown]
# ## Custom ResNet18

# %%
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240130_121814' --optim_code '_1359' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds --visualize_knn
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %%
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240130_133329' --optim_code '_13hi' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %%
# TOP MODEL
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240130_143435' --optim_code '_13hj' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 10]             --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %% [markdown]
# # Use DINOv2 embeddings

# %%
# !python knn/knn_classification.py --num_classes 10 --cp_datetime '20240126_170100' --model_name 'DINOv2' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# KNN Classifier Accuracy on Test Set: 98.70%
# Figure(1200x600)
# Visualization of Embeddings Saved.

# %%
data = np.load('embeddings/DinoV2-CIFAR10-CIFAR100/CIFAR10-DINOV2-BASE/train.npz')
embeddings = data["embeddings"]
embeddings.shape
# Out:
# (50000, 768)
