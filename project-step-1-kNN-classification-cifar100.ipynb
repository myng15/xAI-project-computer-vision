# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/xAI-project-computer-vision

import sys
sys.path.insert(0,'/content/drive/My Drive/Github/xAI-project-computer-vision')

# %pwd
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision
# '/content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision'

# %%
# !pip install torchinfo

# %%
import numpy as np
import random
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import datasets

print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.1.0+cu121
# torchvision version: 0.16.0+cu121

# %%
import models
from utils import print_model_summary, get_available_device, move_to_device, seed_all

device = get_available_device()
print("Device:", device)

seed_all(42)
# Out:
# Device: cpu
#
# Device: cpu
# Random seed 42 has been set.

# %% [markdown]
# # Use simple custom CNNs as feature extractor

# %% [markdown]
# ## Simple custom CNN v1

# %% [markdown]
# ## Simple custom CNN v2

# %% [markdown]
# # Use deeper custom CNNs (based on ResNet) as feature extractor

# %% [markdown]
# ## Simplified custom ResNet

# %%
# TOP MODEL
# !python knn_classification.py --num_classes 100 --cp_datetime '20240130_143121' --optim_code '_1359' --model_name 'resnet_custom_simplified' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResnetCustomSimplified (ResnetCustomSimplified)    [64, 3, 32, 32]      [64, 100]            --                   True
# ├─Sequential (conv_layer_1)                        [64, 3, 32, 32]      [64, 64, 32, 32]     --                   True
# │    └─Conv2d (0)                                  [64, 3, 32, 32]      [64, 64, 32, 32]     1,792                True
# │    └─BatchNorm2d (1)                             [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# │    └─ReLU (2)                                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   --
# ...

# %%
# !python knn_classification.py --num_classes 100 --cp_datetime '20240130_141052' --optim_code '_13hi' --model_name 'resnet_custom_simplified' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResnetCustomSimplified (ResnetCustomSimplified)    [64, 3, 32, 32]      [64, 100]            --                   True
# ├─Sequential (conv_layer_1)                        [64, 3, 32, 32]      [64, 64, 32, 32]     --                   True
# │    └─Conv2d (0)                                  [64, 3, 32, 32]      [64, 64, 32, 32]     1,792                True
# │    └─BatchNorm2d (1)                             [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# │    └─ReLU (2)                                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   --
# ...

# %% [markdown]
# ## Custom ResNet18

# %%
# !python knn/knn_classification.py --num_classes 100 --cp_datetime '20240130_131908' --optim_code '_1359' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds --visualize_knn
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 100]            --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %%
# !python knn/knn_classification.py --num_classes 100 --cp_datetime '20240130_134024' --optim_code '_13hi' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 100]            --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %%
# TOP MODEL
# !python knn/knn_classification.py --num_classes 100 --cp_datetime '20240223_112139' --optim_code '_13hj' --model_name 'resnet18_custom' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cuda
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cuda
#
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                          [64, 3, 32, 32]      [64, 100]            --                   True
# ├─Conv2d (conv1)                         [64, 3, 32, 32]      [64, 64, 32, 32]     1,728                True
# ├─BatchNorm2d (bn1)                      [64, 64, 32, 32]     [64, 64, 32, 32]     128                  True
# ├─Sequential (layer1)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# │    └─BasicBlock (0)                    [64, 64, 32, 32]     [64, 64, 32, 32]     --                   True
# ...

# %% [markdown]
# # Use DINOv2 embeddings

# %%
# !python knn/knn_classification.py --num_classes 100 --cp_datetime '20240223_174500' --model_name 'DINOv2' --batch_size 64 --num_workers 2 --n_neighbors 5 --visualize_embeds
# Out:
# Device: cpu
#
# Random seed 42 has been set.
# Random seed 42 has been set.
# Device: cpu
#
# KNN Classifier Accuracy on Test Embeddings: 89.25%
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision/visualization.py:196: UserWarning: The palette list has more values (103) than needed (100), which may not be intended.
#   sns.scatterplot(x=train_reduced_embeddings[:, 0], y=train_reduced_embeddings[:, 1], hue=train_labels,
# /content/drive/.shortcut-targets-by-id/1Rc4yOY9-4nyo4PuPOLW54tnaNHAfWufd/Github/xAI-project-computer-vision/visualization.py:203: UserWarning: The palette list has more values (103) than needed (100), which may not be intended.
#   sns.scatterplot(x=test_reduced_embeddings[:, 0], y=test_reduced_embeddings[:, 1], hue=test_labels,
# Figure(2000x1000)
# Visualization of Embeddings Saved.
